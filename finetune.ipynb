# %%
import ast

def load_txt_to_dict_list(filepath):
    data = []

    with open(filepath, 'r', encoding='utf-8') as f:
        for line in f:
            line = line.strip()
            if not line:
                continue
            try:
                # Safely evaluate the string to a Python dictionary
                record = ast.literal_eval(line)

                # Extract 'sentence' and 'triple' keys
                sentence = record.get('sentence', '')
                triples = record.get('triple', [])

                data.append({
                    "instruction": "Extract all subject–predicate–object triples from the sentence.",
                    "input": sentence,
                    "output": str(triples)
                })

            except Exception as e:
                print(f" Error on line:\n{line}\n{e}")

    return data

#  Usage
file_path = "train.txt" 
formatted_data = load_txt_to_dict_list(file_path)

# Optional: check a sample
print("Sample formatted data:")
print(formatted_data[0])
# Out:
# Sample formatted data:
# {'instruction': 'Extract all subject–predicate–object triples from the sentence.', 'input': 'The worst hotspot for violence has been in the Palestinian village of Beita, where locals began organising the recent protests after hard-line Jewish settlers set up a new outpost on land claimed by Palestinian olive farmers.', 'output': "[['Palestinian', 'job_title', 'olive farmers']]"}

# %%
import ast

def load_txt_to_dict_list(filepath):
    data = []

    with open(filepath, 'r', encoding='utf-8') as f:
        for line in f:
            line = line.strip()
            if not line:
                continue
            try:
                # Safely evaluate the string to a Python dictionary
                record = ast.literal_eval(line)

                # Extract 'sentence' and 'triple' keys
                sentence = record.get('sentence', '')
                triples = record.get('triple', [])

                data.append({
                    "instruction": "Extract all subject–predicate–object triples from the sentence.",
                    "input": sentence,
                    "output": str(triples)
                })

            except Exception as e:
                print(f" Error on line:\n{line}\n{e}")

    return data

#  Usage
file_path = "test.txt" 
formatted_data_test = load_txt_to_dict_list(file_path)

# Optional: check a sample
print("Sample formatted data:")
print(formatted_data_test[0])
# Out:
# Sample formatted data:
# {'instruction': 'Extract all subject–predicate–object triples from the sentence.', 'input': 'The rarified space is the cavernous outdoor concert location in the middle of the Calgary Stampede grounds that’s known as Nashville North, where people lingering at picnic tables sip Molson Canadian and Budweiser as musicians belt out covers of Tim McGraw and Toby Keith.', 'output': "[['Nashville North', 'known_as', 'outdoor concert'], ['Tim McGraw', 'job_title', 'musician'], ['Toby Keith', 'job_title', 'musician']]"}

# %%
# %pip install datasets
# Out:
# Collecting datasets
#   Downloading datasets-3.5.1-py3-none-any.whl.metadata (19 kB)
# Collecting filelock (from datasets)
#   Using cached filelock-3.18.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting numpy>=1.17 (from datasets)
#   Using cached numpy-2.2.5-cp312-cp312-win_amd64.whl.metadata (60 kB)
# Collecting pyarrow>=15.0.0 (from datasets)
#   Downloading pyarrow-20.0.0-cp312-cp312-win_amd64.whl.metadata (3.4 kB)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Using cached dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Collecting pandas (from datasets)
#   Using cached pandas-2.2.3-cp312-cp312-win_amd64.whl.metadata (19 kB)
# Collecting requests>=2.32.2 (from datasets)
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# Collecting tqdm>=4.66.3 (from datasets)
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.5.0-cp312-cp312-win_amd64.whl.metadata (13 kB)
# Collecting multiprocess<0.70.17 (from datasets)
#   Downloading multiprocess-0.70.16-py312-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2025.3.0,>=2023.1.0 (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets)
#   Downloading fsspec-2025.3.0-py3-none-any.whl.metadata (11 kB)
# Collecting aiohttp (from datasets)
#   Downloading aiohttp-3.11.18-cp312-cp312-win_amd64.whl.metadata (8.0 kB)
# Collecting huggingface-hub>=0.24.0 (from datasets)
#   Downloading huggingface_hub-0.30.2-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: packaging in c:\users\mohan\appdata\roaming\python\python312\site-packages (from datasets) (24.2)
# Collecting pyyaml>=5.1 (from datasets)
#   Using cached PyYAML-6.0.2-cp312-cp312-win_amd64.whl.metadata (2.1 kB)
# Collecting aiohappyeyeballs>=2.3.0 (from aiohttp->datasets)
#   Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.1.2 (from aiohttp->datasets)
#   Using cached aiosignal-1.3.2-py2.py3-none-any.whl.metadata (3.8 kB)
# Collecting attrs>=17.3.0 (from aiohttp->datasets)
#   Using cached attrs-25.3.0-py3-none-any.whl.metadata (10 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp->datasets)
#   Downloading frozenlist-1.6.0-cp312-cp312-win_amd64.whl.metadata (16 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp->datasets)
#   Downloading multidict-6.4.3-cp312-cp312-win_amd64.whl.metadata (5.5 kB)
# Collecting propcache>=0.2.0 (from aiohttp->datasets)
#   Downloading propcache-0.3.1-cp312-cp312-win_amd64.whl.metadata (11 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp->datasets)
#   Downloading yarl-1.20.0-cp312-cp312-win_amd64.whl.metadata (74 kB)
# Collecting idna>=2.0 (from yarl<2.0,>=1.17.0->aiohttp->datasets)
#   Using cached idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting typing-extensions>=3.7.4.3 (from huggingface-hub>=0.24.0->datasets)
#   Downloading typing_extensions-4.13.2-py3-none-any.whl.metadata (3.0 kB)
# Collecting charset-normalizer<4,>=2 (from requests>=2.32.2->datasets)
#   Using cached charset_normalizer-3.4.1-cp312-cp312-win_amd64.whl.metadata (36 kB)
# Collecting urllib3<3,>=1.21.1 (from requests>=2.32.2->datasets)
#   Downloading urllib3-2.4.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting certifi>=2017.4.17 (from requests>=2.32.2->datasets)
#   Downloading certifi-2025.4.26-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: colorama in c:\users\mohan\appdata\roaming\python\python312\site-packages (from tqdm>=4.66.3->datasets) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\mohan\appdata\roaming\python\python312\site-packages (from pandas->datasets) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas->datasets)
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas->datasets)
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in c:\users\mohan\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Downloading datasets-3.5.1-py3-none-any.whl (491 kB)
# Using cached dill-0.3.8-py3-none-any.whl (116 kB)
# Downloading fsspec-2025.3.0-py3-none-any.whl (193 kB)
# Downloading multiprocess-0.70.16-py312-none-any.whl (146 kB)
# Downloading aiohttp-3.11.18-cp312-cp312-win_amd64.whl (439 kB)
# Downloading multidict-6.4.3-cp312-cp312-win_amd64.whl (38 kB)
# Downloading yarl-1.20.0-cp312-cp312-win_amd64.whl (92 kB)
# Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Using cached aiosignal-1.3.2-py2.py3-none-any.whl (7.6 kB)
# Using cached attrs-25.3.0-py3-none-any.whl (63 kB)
# Downloading frozenlist-1.6.0-cp312-cp312-win_amd64.whl (120 kB)
# Downloading huggingface_hub-0.30.2-py3-none-any.whl (481 kB)
# Using cached idna-3.10-py3-none-any.whl (70 kB)
# Using cached numpy-2.2.5-cp312-cp312-win_amd64.whl (12.6 MB)
# Downloading propcache-0.3.1-cp312-cp312-win_amd64.whl (44 kB)
# Downloading pyarrow-20.0.0-cp312-cp312-win_amd64.whl (25.7 MB)
#    ---------------------------------------- 0.0/25.7 MB ? eta -:--:--
#    - -------------------------------------- 0.8/25.7 MB 5.6 MB/s eta 0:00:05
#    --- ------------------------------------ 2.1/25.7 MB 5.1 MB/s eta 0:00:05
#    ---- ----------------------------------- 3.1/25.7 MB 5.1 MB/s eta 0:00:05
#    ------ --------------------------------- 4.2/25.7 MB 5.0 MB/s eta 0:00:05
#    -------- ------------------------------- 5.2/25.7 MB 5.1 MB/s eta 0:00:05
#    --------- ------------------------------ 6.3/25.7 MB 5.1 MB/s eta 0:00:04
#    ----------- ---------------------------- 7.3/25.7 MB 5.1 MB/s eta 0:00:04
#    ------------- -------------------------- 8.4/25.7 MB 5.1 MB/s eta 0:00:04
#    -------------- ------------------------- 9.4/25.7 MB 5.1 MB/s eta 0:00:04
#    ---------------- ----------------------- 10.5/25.7 MB 5.1 MB/s eta 0:00:03
#    ----------------- ---------------------- 11.5/25.7 MB 5.1 MB/s eta 0:00:03
#    ------------------- -------------------- 12.6/25.7 MB 5.1 MB/s eta 0:00:03
#    --------------------- ------------------ 13.6/25.7 MB 5.1 MB/s eta 0:00:03
#    ----------------------- ---------------- 14.9/25.7 MB 5.1 MB/s eta 0:00:03
#    ------------------------ --------------- 16.0/25.7 MB 5.1 MB/s eta 0:00:02
#    -------------------------- ------------- 17.0/25.7 MB 5.1 MB/s eta 0:00:02
#    ---------------------------- ----------- 18.1/25.7 MB 5.1 MB/s eta 0:00:02
#    ----------------------------- ---------- 19.1/25.7 MB 5.1 MB/s eta 0:00:02
#    ------------------------------- -------- 20.2/25.7 MB 5.1 MB/s eta 0:00:02
#    -------------------------------- ------- 21.0/25.7 MB 5.1 MB/s eta 0:00:01
#    ---------------------------------- ----- 22.0/25.7 MB 5.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 23.1/25.7 MB 5.1 MB/s eta 0:00:01
#    ------------------------------------- -- 24.1/25.7 MB 5.1 MB/s eta 0:00:01
#    ---------------------------------------  25.2/25.7 MB 5.1 MB/s eta 0:00:01
#    ---------------------------------------  25.4/25.7 MB 5.1 MB/s eta 0:00:01
#    ---------------------------------------  25.4/25.7 MB 5.1 MB/s eta 0:00:01
#    ---------------------------------------- 25.7/25.7 MB 4.7 MB/s eta 0:00:00
# Using cached PyYAML-6.0.2-cp312-cp312-win_amd64.whl (156 kB)
# Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Using cached charset_normalizer-3.4.1-cp312-cp312-win_amd64.whl (102 kB)
# Downloading urllib3-2.4.0-py3-none-any.whl (128 kB)
# Downloading certifi-2025.4.26-py3-none-any.whl (159 kB)
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Downloading typing_extensions-4.13.2-py3-none-any.whl (45 kB)
# Using cached filelock-3.18.0-py3-none-any.whl (16 kB)
# Using cached pandas-2.2.3-cp312-cp312-win_amd64.whl (11.5 MB)
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Downloading xxhash-3.5.0-cp312-cp312-win_amd64.whl (30 kB)
# Installing collected packages: pytz, xxhash, urllib3, tzdata, typing-extensions, tqdm, pyyaml, pyarrow, propcache, numpy, multidict, idna, fsspec, frozenlist, filelock, dill, charset-normalizer, certifi, attrs, aiohappyeyeballs, yarl, requests, pandas, multiprocess, aiosignal, huggingface-hub, aiohttp, datasets
#
#    ----------------------------------------  0/28 [pytz]
#    ----------------------------------------  0/28 [pytz]
#    ----------------------------------------  0/28 [pytz]
#    -- -------------------------------------  2/28 [urllib3]
#    -- -------------------------------------  2/28 [urllib3]
#    ---- -----------------------------------  3/28 [tzdata]
#    ---- -----------------------------------  3/28 [tzdata]
#    ---- -----------------------------------  3/28 [tzdata]
#    ---- -----------------------------------  3/28 [tzdata]
#    ------- --------------------------------  5/28 [tqdm]
#    ------- --------------------------------  5/28 [tqdm]
#    -------- -------------------------------  6/28 [pyyaml]
#    ---------- -----------------------------  7/28 [pyarrow]
#    ---------- -----------------------------  7/28 [pyarrow]
#    ---------- -----------------------------  7/28 [pyarrow]
#    ---------- -----------------------------  7/28 [pyarrow]
#    ---------- -----------------------------  7/28 [pyarrow]
#    ---------- -----------------------------  7/28 [pyarrow]
#    ---------- -----------------------------  7/28 [pyarrow]
#    ---------- -----------------------------  7/28 [pyarrow]
#    ---------- -----------------------------  7/28 [pyarrow]
#    ---------- -----------------------------  7/28 [pyarrow]
#    ---------- -----------------------------  7/28 [pyarrow]
#    ---------- -----------------------------  7/28 [pyarrow]
#    ---------- -----------------------------  7/28 [pyarrow]
#    ----------- ----------------------------  8/28 [propcache]
#    ------------ ---------------------------  9/28 [numpy]
#    ------------ ---------------------------  9/28 [numpy]
#    ------------ ---------------------------  9/28 [numpy]
#    ------------ ---------------------------  9/28 [numpy]
#    ------------ ---------------------------  9/28 [numpy]
#    ------------ ---------------------------  9/28 [numpy]
#    ------------ ---------------------------  9/28 [numpy]
#    ------------ ---------------------------  9/28 [numpy]
#    ------------ ---------------------------  9/28 [numpy]
#    ------------ ---------------------------  9/28 [numpy]
#    ------------ ---------------------------  9/28 [numpy]
#    ------------ ---------------------------  9/28 [numpy]
#    ------------ ---------------------------  9/28 [numpy]
#    ------------ ---------------------------  9/28 [numpy]
#    ------------ ---------------------------  9/28 [numpy]
#    ------------ ---------------------------  9/28 [numpy]
#    ------------ ---------------------------  9/28 [numpy]
#    ------------ ---------------------------  9/28 [numpy]
#    ------------ ---------------------------  9/28 [numpy]
#    ------------ ---------------------------  9/28 [numpy]
#    ------------ ---------------------------  9/28 [numpy]
#    ------------ ---------------------------  9/28 [numpy]
#    ------------ ---------------------------  9/28 [numpy]
#    ------------ ---------------------------  9/28 [numpy]
#    ------------ ---------------------------  9/28 [numpy]
#    ------------ ---------------------------  9/28 [numpy]
#    ------------ ---------------------------  9/28 [numpy]
#    ------------ ---------------------------  9/28 [numpy]
#    ------------ ---------------------------  9/28 [numpy]
#    ------------ ---------------------------  9/28 [numpy]
#    ------------ ---------------------------  9/28 [numpy]
#    --------------- ------------------------ 11/28 [idna]
#    ----------------- ---------------------- 12/28 [fsspec]
#    ----------------- ---------------------- 12/28 [fsspec]
#    ----------------- ---------------------- 12/28 [fsspec]
#    --------------------- ------------------ 15/28 [dill]
#    --------------------- ------------------ 15/28 [dill]
#    ---------------------- ----------------- 16/28 [charset-normalizer]
#    ------------------------- -------------- 18/28 [attrs]
#    ---------------------------- ----------- 20/28 [yarl]
#    ------------------------------- -------- 22/28 [pandas]
#    ------------------------------- -------- 22/28 [pandas]
#    ------------------------------- -------- 22/28 [pandas]
#    ------------------------------- -------- 22/28 [pandas]
#    ------------------------------- -------- 22/28 [pandas]
#    ------------------------------- -------- 22/28 [pandas]
#    ------------------------------- -------- 22/28 [pandas]
#    ------------------------------- -------- 22/28 [pandas]
#    ------------------------------- -------- 22/28 [pandas]
#    ------------------------------- -------- 22/28 [pandas]
#    ------------------------------- -------- 22/28 [pandas]
#    ------------------------------- -------- 22/28 [pandas]
#    ------------------------------- -------- 22/28 [pandas]
#    ------------------------------- -------- 22/28 [pandas]
#    ------------------------------- -------- 22/28 [pandas]
#    ------------------------------- -------- 22/28 [pandas]
#    ------------------------------- -------- 22/28 [pandas]
#    ------------------------------- -------- 22/28 [pandas]
#    ------------------------------- -------- 22/28 [pandas]
#    ------------------------------- -------- 22/28 [pandas]
#    ------------------------------- -------- 22/28 [pandas]
#    ------------------------------- -------- 22/28 [pandas]
#    ------------------------------- -------- 22/28 [pandas]
#    ------------------------------- -------- 22/28 [pandas]
#    ------------------------------- -------- 22/28 [pandas]
#    ------------------------------- -------- 22/28 [pandas]
#    ------------------------------- -------- 22/28 [pandas]
#    ------------------------------- -------- 22/28 [pandas]
#    ------------------------------- -------- 22/28 [pandas]
#    ------------------------------- -------- 22/28 [pandas]
#    ------------------------------- -------- 22/28 [pandas]
#    ------------------------------- -------- 22/28 [pandas]
#    ------------------------------- -------- 22/28 [pandas]
#    ------------------------------- -------- 22/28 [pandas]
#    ------------------------------- -------- 22/28 [pandas]
#    ------------------------------- -------- 22/28 [pandas]
#    ------------------------------- -------- 22/28 [pandas]
#    ------------------------------- -------- 22/28 [pandas]
#    ------------------------------- -------- 22/28 [pandas]
#    ------------------------------- -------- 22/28 [pandas]
#    ------------------------------- -------- 22/28 [pandas]
#    ------------------------------- -------- 22/28 [pandas]
#    ------------------------------- -------- 22/28 [pandas]
#    ------------------------------- -------- 22/28 [pandas]
#    ------------------------------- -------- 22/28 [pandas]
#    ------------------------------- -------- 22/28 [pandas]
#    ------------------------------- -------- 22/28 [pandas]
#    ------------------------------- -------- 22/28 [pandas]
#    ------------------------------- -------- 22/28 [pandas]
#    ------------------------------- -------- 22/28 [pandas]
#    ------------------------------- -------- 22/28 [pandas]
#    ------------------------------- -------- 22/28 [pandas]
#    ------------------------------- -------- 22/28 [pandas]
#    ------------------------------- -------- 22/28 [pandas]
#    ------------------------------- -------- 22/28 [pandas]
#    ------------------------------- -------- 22/28 [pandas]
#    ------------------------------- -------- 22/28 [pandas]
#    ------------------------------- -------- 22/28 [pandas]
#    ------------------------------- -------- 22/28 [pandas]
#    ------------------------------- -------- 22/28 [pandas]
#    ------------------------------- -------- 22/28 [pandas]
#    ------------------------------- -------- 22/28 [pandas]
#    ------------------------------- -------- 22/28 [pandas]
#    ------------------------------- -------- 22/28 [pandas]
#    ------------------------------- -------- 22/28 [pandas]
#    ------------------------------- -------- 22/28 [pandas]
#    ------------------------------- -------- 22/28 [pandas]
#    ------------------------------- -------- 22/28 [pandas]
#    ------------------------------- -------- 22/28 [pandas]
#    ------------------------------- -------- 22/28 [pandas]
#    ------------------------------- -------- 22/28 [pandas]
#    ------------------------------- -------- 22/28 [pandas]
#    ------------------------------- -------- 22/28 [pandas]
#    ------------------------------- -------- 22/28 [pandas]
#    ------------------------------- -------- 22/28 [pandas]
#    ------------------------------- -------- 22/28 [pandas]
#    ------------------------------- -------- 22/28 [pandas]
#    ------------------------------- -------- 22/28 [pandas]
#    ------------------------------- -------- 22/28 [pandas]
#    -------------------------------- ------- 23/28 [multiprocess]
#    -------------------------------- ------- 23/28 [multiprocess]
#    ----------------------------------- ---- 25/28 [huggingface-hub]
#    ----------------------------------- ---- 25/28 [huggingface-hub]
#    ----------------------------------- ---- 25/28 [huggingface-hub]
#    ----------------------------------- ---- 25/28 [huggingface-hub]
#    ----------------------------------- ---- 25/28 [huggingface-hub]
#    ----------------------------------- ---- 25/28 [huggingface-hub]
#    ----------------------------------- ---- 25/28 [huggingface-hub]
#    ------------------------------------- -- 26/28 [aiohttp]
#    ------------------------------------- -- 26/28 [aiohttp]
#    ------------------------------------- -- 26/28 [aiohttp]
#    ------------------------------------- -- 26/28 [aiohttp]
#    -------------------------------------- - 27/28 [datasets]
#    -------------------------------------- - 27/28 [datasets]
#    -------------------------------------- - 27/28 [datasets]
#    -------------------------------------- - 27/28 [datasets]
#    -------------------------------------- - 27/28 [datasets]
#    -------------------------------------- - 27/28 [datasets]
#    ---------------------------------------- 28/28 [datasets]
#
# Successfully installed aiohappyeyeballs-2.6.1 aiohttp-3.11.18 aiosignal-1.3.2 attrs-25.3.0 certifi-2025.4.26 charset-normalizer-3.4.1 datasets-3.5.1 dill-0.3.8 filelock-3.18.0 frozenlist-1.6.0 fsspec-2025.3.0 huggingface-hub-0.30.2 idna-3.10 multidict-6.4.3 multiprocess-0.70.16 numpy-2.2.5 pandas-2.2.3 propcache-0.3.1 pyarrow-20.0.0 pytz-2025.2 pyyaml-6.0.2 requests-2.32.3 tqdm-4.67.1 typing-extensions-4.13.2 tzdata-2025.2 urllib3-2.4.0 xxhash-3.5.0 yarl-1.20.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from datasets import Dataset

dataset_train = Dataset.from_list(formatted_data)

# %%
dataset_test = Dataset.from_list(formatted_data_test)

# %%
dataset_train
# Out:
# Dataset({
#     features: ['instruction', 'input', 'output'],
#     num_rows: 414
# })

# %%
dataset_test
# Out:
# Dataset({
#     features: ['instruction', 'input', 'output'],
#     num_rows: 271
# })

# %%
dataset_train[0]
# Out:
# {'instruction': 'Extract all subject–predicate–object triples from the sentence.',
#  'input': 'The worst hotspot for violence has been in the Palestinian village of Beita, where locals began organising the recent protests after hard-line Jewish settlers set up a new outpost on land claimed by Palestinian olive farmers.',
#  'output': "[['Palestinian', 'job_title', 'olive farmers']]"}

# %%
dataset_test[0]
# Out:
# {'instruction': 'Extract all subject–predicate–object triples from the sentence.',
#  'input': 'The rarified space is the cavernous outdoor concert location in the middle of the Calgary Stampede grounds that’s known as Nashville North, where people lingering at picnic tables sip Molson Canadian and Budweiser as musicians belt out covers of Tim McGraw and Toby Keith.',
#  'output': "[['Nashville North', 'known_as', 'outdoor concert'], ['Tim McGraw', 'job_title', 'musician'], ['Toby Keith', 'job_title', 'musician']]"}

# %%
import ast

def validate_dataset(dataset):
    invalid_entries = []
    multiple_triple_count = 0

    for idx, item in enumerate(dataset):
        try:
            # Check required keys
            if not all(k in item for k in ['instruction', 'input', 'output']):
                invalid_entries.append((idx, "Missing required keys"))
                continue

            output_str = item['output'].strip()

            # Check if output string starts and ends with valid brackets
            if not (output_str.startswith("[") and output_str.endswith("]")):
                invalid_entries.append((idx, "Output format invalid or not properly closed"))
                continue

            # Parse the output string
            triples = ast.literal_eval(output_str)

            if not isinstance(triples, list):
                invalid_entries.append((idx, "Output is not a list"))
                continue

            # Check if each element is a valid triple
            if not all(isinstance(triple, list) and len(triple) == 3 for triple in triples):
                invalid_entries.append((idx, "Each triple must be a list of 3 elements"))
                continue

            # Count multiple triples
            if len(triples) > 1:
                multiple_triple_count += 1

        except Exception as e:
            invalid_entries.append((idx, f"Error parsing output: {e}"))

    print(f"\n Validation completed.")
    print(f"Total entries: {len(dataset)}")
    print(f"Total entries with multiple triples: {multiple_triple_count}")
    print(f" Total invalid entries: {len(invalid_entries)}")

    if invalid_entries:
        print("\n Sample invalid entries:")
        for i, msg in invalid_entries[:5]:  # Display first 5 issues
            print(f" - Row {i}: {msg}")
    else:
        print(" All entries are valid.")

# Example usage:
# validate_dataset(dataset)

# %%
validate_dataset(dataset_train)
# Out:
#  Validation completed.
# Total entries: 414
# Total entries with multiple triples: 96
#  Total invalid entries: 0
#  All entries are valid.

# %%
validate_dataset(dataset_test)
# Out:
#  Validation completed.
# Total entries: 271
# Total entries with multiple triples: 161
#  Total invalid entries: 0
#  All entries are valid.

# %%
# %pip install -U spacy
# %python -m spacy download en_core_web_sm
# Out:
# Requirement already satisfied: spacy in c:\vamsi\study\ss25\track2\exercise\ex2\.conda\lib\site-packages (3.8.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in c:\vamsi\study\ss25\track2\exercise\ex2\.conda\lib\site-packages (from spacy) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in c:\vamsi\study\ss25\track2\exercise\ex2\.conda\lib\site-packages (from spacy) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in c:\vamsi\study\ss25\track2\exercise\ex2\.conda\lib\site-packages (from spacy) (1.0.12)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in c:\vamsi\study\ss25\track2\exercise\ex2\.conda\lib\site-packages (from spacy) (2.0.11)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in c:\vamsi\study\ss25\track2\exercise\ex2\.conda\lib\site-packages (from spacy) (3.0.9)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in c:\vamsi\study\ss25\track2\exercise\ex2\.conda\lib\site-packages (from spacy) (8.3.6)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in c:\vamsi\study\ss25\track2\exercise\ex2\.conda\lib\site-packages (from spacy) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in c:\vamsi\study\ss25\track2\exercise\ex2\.conda\lib\site-packages (from spacy) (2.5.1)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in c:\vamsi\study\ss25\track2\exercise\ex2\.conda\lib\site-packages (from spacy) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.1.0 in c:\vamsi\study\ss25\track2\exercise\ex2\.conda\lib\site-packages (from spacy) (0.4.1)
# Requirement already satisfied: typer<1.0.0,>=0.3.0 in c:\vamsi\study\ss25\track2\exercise\ex2\.conda\lib\site-packages (from spacy) (0.15.3)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in c:\vamsi\study\ss25\track2\exercise\ex2\.conda\lib\site-packages (from spacy) (4.67.1)
# Requirement already satisfied: numpy>=1.19.0 in c:\vamsi\study\ss25\track2\exercise\ex2\.conda\lib\site-packages (from spacy) (2.2.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in c:\vamsi\study\ss25\track2\exercise\ex2\.conda\lib\site-packages (from spacy) (2.32.3)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in c:\vamsi\study\ss25\track2\exercise\ex2\.conda\lib\site-packages (from spacy) (2.11.4)
# Requirement already satisfied: jinja2 in c:\vamsi\study\ss25\track2\exercise\ex2\.conda\lib\site-packages (from spacy) (3.1.6)
# Requirement already satisfied: setuptools in c:\vamsi\study\ss25\track2\exercise\ex2\.conda\lib\site-packages (from spacy) (78.1.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\mohan\appdata\roaming\python\python312\site-packages (from spacy) (24.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in c:\vamsi\study\ss25\track2\exercise\ex2\.conda\lib\site-packages (from spacy) (3.5.0)
# Requirement already satisfied: language-data>=1.2 in c:\vamsi\study\ss25\track2\exercise\ex2\.conda\lib\site-packages (from langcodes<4.0.0,>=3.2.0->spacy) (1.3.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\vamsi\study\ss25\track2\exercise\ex2\.conda\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in c:\vamsi\study\ss25\track2\exercise\ex2\.conda\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (2.33.2)
# Requirement already satisfied: typing-extensions>=4.12.2 in c:\vamsi\study\ss25\track2\exercise\ex2\.conda\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (4.13.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in c:\vamsi\study\ss25\track2\exercise\ex2\.conda\lib\site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy) (0.4.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\vamsi\study\ss25\track2\exercise\ex2\.conda\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\vamsi\study\ss25\track2\exercise\ex2\.conda\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\vamsi\study\ss25\track2\exercise\ex2\.conda\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\vamsi\study\ss25\track2\exercise\ex2\.conda\lib\site-packages (from requests<3.0.0,>=2.13.0->spacy) (2025.4.26)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in c:\vamsi\study\ss25\track2\exercise\ex2\.conda\lib\site-packages (from thinc<8.4.0,>=8.3.4->spacy) (1.3.0)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in c:\vamsi\study\ss25\track2\exercise\ex2\.conda\lib\site-packages (from thinc<8.4.0,>=8.3.4->spacy) (0.1.5)
# Requirement already satisfied: colorama in c:\users\mohan\appdata\roaming\python\python312\site-packages (from tqdm<5.0.0,>=4.38.0->spacy) (0.4.6)
# Requirement already satisfied: click>=8.0.0 in c:\vamsi\study\ss25\track2\exercise\ex2\.conda\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (8.1.8)
# Requirement already satisfied: shellingham>=1.3.0 in c:\vamsi\study\ss25\track2\exercise\ex2\.conda\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (1.5.4)
# Requirement already satisfied: rich>=10.11.0 in c:\vamsi\study\ss25\track2\exercise\ex2\.conda\lib\site-packages (from typer<1.0.0,>=0.3.0->spacy) (14.0.0)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in c:\vamsi\study\ss25\track2\exercise\ex2\.conda\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy) (0.21.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in c:\vamsi\study\ss25\track2\exercise\ex2\.conda\lib\site-packages (from weasel<0.5.0,>=0.1.0->spacy) (7.1.0)
# Requirement already satisfied: wrapt in c:\vamsi\study\ss25\track2\exercise\ex2\.conda\lib\site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.1.0->spacy) (1.17.2)
# Requirement already satisfied: marisa-trie>=1.1.0 in c:\vamsi\study\ss25\track2\exercise\ex2\.conda\lib\site-packages (from language-data>=1.2->langcodes<4.0.0,>=3.2.0->spacy) (1.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\vamsi\study\ss25\track2\exercise\ex2\.conda\lib\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\mohan\appdata\roaming\python\python312\site-packages (from rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in c:\vamsi\study\ss25\track2\exercise\ex2\.conda\lib\site-packages (from markdown-it-py>=2.2.0->rich>=10.11.0->typer<1.0.0,>=0.3.0->spacy) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\vamsi\study\ss25\track2\exercise\ex2\.conda\lib\site-packages (from jinja2->spacy) (3.0.2)
# Note: you may need to restart the kernel to use updated packages.
# UsageError: Line magic function `%python` not found (But cell magic `%%python` exists, did you mean that instead?).

# %%
import spacy
print(spacy.info())  # This will show available models
# Out:
# {'spacy_version': '3.8.5', 'location': 'c:\\Vamsi\\Study\\SS25\\Track2\\Exercise\\Ex2\\.conda\\Lib\\site-packages\\spacy', 'platform': 'Windows-11-10.0.26100-SP0', 'python_version': '3.12.9', 'pipelines': {}}

# %%
import spacy
import ast
from datasets import Dataset

# Load English spaCy model
nlp = spacy.load("en_core_web_sm")

def extract_subject_entities(text):
    """
    Uses spaCy to extract named entities that can act as subjects.
    You can customize this more based on your needs (e.g. noun chunks).
    """
    doc = nlp(text)
    subjects = [ent.text for ent in doc.ents]  # Named entities as candidate subjects
    return subjects

def build_subject_conditioned_dataset(dataset):
    new_examples = []

    for row in dataset:
        sentence = row['input']
        all_triples = ast.literal_eval(row['output'])

        # Extract subjects from sentence using spaCy
        subjects_in_text = extract_subject_entities(sentence)

        for triple in all_triples:
            subj, pred, obj = triple

            # Use gold triple's subject if it's in the text (you can customize this)
            if subj in subjects_in_text:
                new_examples.append({
                    "instruction": f"Given the subject entity '{subj}', extract the full triple from the sentence.",
                    "input": sentence,
                    "output": str([subj, pred, obj])
                })

    return Dataset.from_list(new_examples)

# Example usage:
# subject_conditioned_dataset = build_subject_conditioned_dataset(dataset)

# %%
ner_train_dataset = build_subject_conditioned_dataset(dataset_train)

# %%
ner_train_dataset
# Out:
# Dataset({
#     features: ['instruction', 'input', 'output'],
#     num_rows: 409
# })

# %%
ner_train_dataset[0]
# Out:
# {'instruction': "Given the subject entity 'Palestinian', extract the full triple from the sentence.",
#  'input': 'The worst hotspot for violence has been in the Palestinian village of Beita, where locals began organising the recent protests after hard-line Jewish settlers set up a new outpost on land claimed by Palestinian olive farmers.'}

# %%
import spacy
from spacy.lang.en.examples import sentences 

nlp = spacy.load("en_core_web_sm")
doc = nlp("The worst hotspot for violence has been in the Palestinian village of Beita, where locals began organising the recent protests after hard-line Jewish settlers set up a new outpost on land claimed by Palestinian olive farmers")
print(doc.text)
for token in doc:
    print(token.text, token.pos_, token.dep_)
# Out:
# The worst hotspot for violence has been in the Palestinian village of Beita, where locals began organising the recent protests after hard-line Jewish settlers set up a new outpost on land claimed by Palestinian olive farmers
# The DET det
# worst ADJ amod
# hotspot NOUN nsubj
# for ADP prep
# violence NOUN pobj
# has AUX aux
# been AUX ROOT
# in ADP prep
# the DET det
# Palestinian ADJ amod
# village NOUN pobj
# of ADP prep
# Beita PROPN pobj
# , PUNCT punct
# where SCONJ advmod
# locals NOUN nsubj
# began VERB relcl
# organising VERB xcomp
# the DET det
# recent ADJ amod
# protests NOUN dobj
# after SCONJ mark
# hard ADJ amod
# - PUNCT punct
# line NOUN nmod
# Jewish ADJ amod
# settlers NOUN nsubj
# set VERB advcl
# up ADP prt
# a DET det
# new ADJ amod
# outpost NOUN dobj
# on ADP prep
# land NOUN pobj
# claimed VERB acl
# by ADP agent
# Palestinian ADJ amod
# olive NOUN compound
# farmers NOUN pobj

# %%
import spacy

# Load spaCy's English model
nlp = spacy.load("en_core_web_sm")

def extract_spo_triples(sentence):
    doc = nlp(sentence)
    triples = []

    for token in doc:
        # Rule 1: Find subject → verb → object
        if token.dep_ == "nsubj" and token.head.pos_ == "VERB":
            subject = token.text
            verb = token.head
            predicate = verb.text

            # Look for direct object (dobj) or object of preposition (pobj)
            obj = None
            for child in verb.children:
                if child.dep_ in ("dobj", "attr", "pobj", "oprd"):
                    obj = child.text
                elif child.dep_ == "prep":  # handle prep + pobj
                    for subchild in child.children:
                        if subchild.dep_ == "pobj":
                            obj = f"{child.text} {subchild.text}"

            if obj:
                triples.append([subject, predicate, obj])

        # Rule 2: Handle passive voice (agent phrases)
        if token.dep_ == "agent" and token.head.dep_ == "acl":
            agent = list(token.children)
            if agent:
                subject = agent[0].text
                predicate = "claimed_by"
                obj = token.head.head.text  # e.g. land claimed by X
                triples.append([subject, predicate, obj])

    return triples

# %%
sentence = "The worst hotspot for violence has been in the Palestinian village of Beita, where locals began organising the recent protests after hard-line Jewish settlers set up a new outpost on land claimed by Palestinian olive farmers"

# %%
extract_spo_triples(sentence)
# Out:
# [['settlers', 'set', 'outpost'], ['farmers', 'claimed_by', 'land']]

# %%
import spacy

# Load spaCy model
nlp = spacy.load("en_core_web_sm")

def extract_all_spo_triples(text):
    doc = nlp(text)
    triples = []

    for token in doc:
        # -------- Rule 1: Active voice (nsubj → verb → dobj/pobj) --------
        if token.dep_ == "nsubj" and token.head.pos_ == "VERB":
            subject = token.text
            verb = token.head
            predicate = verb.lemma_  # Use lemma to normalize (e.g., "set up" → "set")

            # Find object
            obj = None
            for child in verb.children:
                if child.dep_ == "dobj":
                    obj = child.text
                elif child.dep_ == "prep":
                    for subchild in child.children:
                        if subchild.dep_ == "pobj":
                            obj = subchild.text

            if obj:
                triples.append([subject, predicate, obj])

        # -------- Rule 2: Passive voice (e.g., "land claimed by farmers") --------
        if token.dep_ == "agent" and token.head.dep_ == "acl":
            verb = token.head.lemma_
            passive_obj = token.head.head.text
            agent = None
            for child in token.children:
                if child.pos_ in ["NOUN", "PROPN"]:
                    agent = child.text

            if agent:
                triples.append([agent, f"{verb}_by", passive_obj])

    return triples

# %%
extract_all_spo_triples(sentence)
# Out:
# [['settlers', 'set', 'outpost'], ['farmers', 'claim_by', 'land']]

# %%
import spacy
import ast
from datasets import Dataset

# Load spaCy model
nlp = spacy.load("en_core_web_sm")

def extract_spo_triples(sentence):
    """
    Extract subject-predicate-object triples from sentence using dependency parsing.
    """
    doc = nlp(sentence)
    triples = []

    for token in doc:
        # Active: subject → verb → object
        if token.dep_ == "nsubj" and token.head.pos_ == "VERB":
            subject = token.text
            verb = token.head.lemma_
            obj = None

            for child in token.head.children:
                if child.dep_ in ("dobj", "attr", "oprd"):
                    obj = child.text
                elif child.dep_ == "prep":
                    for subchild in child.children:
                        if subchild.dep_ == "pobj":
                            obj = subchild.text

            if obj:
                triples.append([subject, verb, obj])

        # Passive: object ← verb ← agent
        if token.dep_ == "agent" and token.head.dep_ == "acl":
            agent = None
            for child in token.children:
                if child.pos_ in ["NOUN", "PROPN"]:
                    agent = child.text

            passive_obj = token.head.head.text
            if agent:
                triples.append([agent, f"{token.head.lemma_}_by", passive_obj])

    return triples

def build_subject_conditioned_dataset(dataset):
    """
    Creates dataset with subject-conditioned prompts from gold and extracted triples.
    """
    new_examples = []

    for row in dataset:
        sentence = row["input"]

        # 1. Gold triples
        try:
            gold_triples = ast.literal_eval(row["output"])
        except:
            gold_triples = []

        for subj, pred, obj in gold_triples:
            new_examples.append({
                "instruction": f"Given the subject entity '{subj}', extract the full triple from the sentence.",
                "input": sentence,
                "output": str([subj, pred, obj])
            })

        # 2. Extracted triples
        extracted_triples = extract_spo_triples(sentence)
        for subj, pred, obj in extracted_triples:
            # Avoid duplicate gold triples
            if [subj, pred, obj] not in gold_triples:
                new_examples.append({
                    "instruction": f"Given the subject entity '{subj}', extract the full triple from the sentence.",
                    "input": sentence,
                    "output": str([subj, pred, obj])
                })

    return Dataset.from_list(new_examples)

# %%
new_set = build_subject_conditioned_dataset(dataset_train)

# %%
new_set
# Out:
# Dataset({
#     features: ['instruction', 'input', 'output'],
#     num_rows: 1027
# })

# %%
for i in new_set:
    print(i)
# Out:
# {'instruction': "Given the subject entity 'Palestinian', extract the full triple from the sentence.", 'input': 'The worst hotspot for violence has been in the Palestinian village of Beita, where locals began organising the recent protests after hard-line Jewish settlers set up a new outpost on land claimed by Palestinian olive farmers.', 'output': "['Palestinian', 'job_title', 'olive farmers']"}
# {'instruction': "Given the subject entity 'settlers', extract the full triple from the sentence.", 'input': 'The worst hotspot for violence has been in the Palestinian village of Beita, where locals began organising the recent protests after hard-line Jewish settlers set up a new outpost on land claimed by Palestinian olive farmers.', 'output': "['settlers', 'set', 'outpost']"}
# {'instruction': "Given the subject entity 'farmers', extract the full triple from the sentence.", 'input': 'The worst hotspot for violence has been in the Palestinian village of Beita, where locals began organising the recent protests after hard-line Jewish settlers set up a new outpost on land claimed by Palestinian olive farmers.', 'output': "['farmers', 'claim_by', 'land']"}
# {'instruction': "Given the subject entity 'Yolande Knell', extract the full triple from the sentence.", 'input': "The BBC's Middle East Correspondent, Yolande Knell reports.", 'output': '[\'Yolande Knell\', \'job_title\', "BBC\'s Middle East Correspondent"]'}
# {'instruction': "Given the subject entity 'Bashar al-Assad', extract the full triple from the sentence.", 'input': "Human rights groups believe that thousands of people have been executed by President Bashar al-Assad's government since the civil war began in 2011.", 'output': "['Bashar al-Assad', 'job_title', 'president']"}
# {'instruction': "Given the subject entity 'war', extract the full triple from the sentence.", 'input': "Human rights groups believe that thousands of people have been executed by President Bashar al-Assad's government since the civil war began in 2011.", 'output': "['war', 'begin', '2011']"}
# {'instruction': "Given the subject entity 'Vanessa Bryant', extract the full triple from the sentence.", 'input': 'Vanessa Bryant, the widow of Kobe Bryant, said she learned about the death of her husband by seeing "RIP Kobe" notifications on her phone.', 'output': "['Vanessa Bryant', 'spouse', 'Kobe Bryant']"}
# {'instruction': "Given the subject entity 'she', extract the full triple from the sentence.", 'input': 'Vanessa Bryant, the widow of Kobe Bryant, said she learned about the death of her husband by seeing "RIP Kobe" notifications on her phone.', 'output': "['she', 'learn', 'death']"}
# {'instruction': "Given the subject entity 'Alex Villanueva', extract the full triple from the sentence.", 'input': 'Ms Bryant said that she had asked Sheriff Alex Villanueva to make sure nobody took photos at the scene.', 'output': "['Alex Villanueva', 'job_title', 'Sheriff']"}
# {'instruction': "Given the subject entity 'she', extract the full triple from the sentence.", 'input': 'Ms Bryant said that she had asked Sheriff Alex Villanueva to make sure nobody took photos at the scene.', 'output': "['she', 'ask', 'Villanueva']"}
# {'instruction': "Given the subject entity 'nobody', extract the full triple from the sentence.", 'input': 'Ms Bryant said that she had asked Sheriff Alex Villanueva to make sure nobody took photos at the scene.', 'output': "['nobody', 'take', 'scene']"}
# {'instruction': "Given the subject entity 'Jonathan Marcus', extract the full triple from the sentence.", 'input': 'So how big a deal is this, asks Jonathan Marcus of the Strategy and Security Institute, University of Exeter.', 'output': "['Jonathan Marcus', 'member_of', 'Strategy and Security Institute']"}
# {'instruction': "Given the subject entity 'Jeffrey Lewis', extract the full triple from the sentence.", 'input': 'China\'s denial is "an act of obfuscation" says Jeffrey Lewis, director of the East Asia Non-Proliferation Program at the Middlebury Institute of International Studies at Monterey, California, because the story has been confirmed by US officials speaking to other media.', 'output': "['Jeffrey Lewis', 'director_of', 'East Asia Non-Proliferation Program']"}
# {'instruction': "Given the subject entity 'Aaron Stein', extract the full triple from the sentence.", 'input': 'Both the FT story and the Chinese denial could be right, says Aaron Stein, director of research at the Foreign Policy Institute in Philadelphia.', 'output': "['Aaron Stein', 'director_of', 'Foreign Policy Institute']"}
# {'instruction': "Given the subject entity 'Foreign Policy Institute', extract the full triple from the sentence.", 'input': 'Both the FT story and the Chinese denial could be right, says Aaron Stein, director of research at the Foreign Policy Institute in Philadelphia.', 'output': "['Foreign Policy Institute', 'headquartered_in', 'Philadelphia']"}
# {'instruction': "Given the subject entity 'James Action', extract the full triple from the sentence.", 'input': "But some experts would disagree and don't believe this test by China creates a new threat. James Acton of the Carnegie Endowment for International Peace says the US has been vulnerable to nuclear attack by China since at least the 1980s.", 'output': "['James Action', 'member_of', 'Carnegie Endowment for International Peace']"}
# {'instruction': "Given the subject entity 'Irish consulate', extract the full triple from the sentence.", 'input': 'Mr Coveney was in Wales for the inaugural Wales-Ireland Forum and the official opening of the Irish Consulate in Cardiff.', 'output': "['Irish consulate', 'located_in', 'Cardiff']"}
# {'instruction': "Given the subject entity 'Maroš Šefčovič', extract the full triple from the sentence.", 'input': 'The EU and UK are set for an intense round of negotiations in the coming weeks after European Commission vice president Maroš Šefčovič unveiled a range of proposals aimed at cutting the red tape the\xa0Northern Ireland Protocol\xa0has imposed on moving goods from Great Britain to Northern Ireland.', 'output': "['Maroš Šefčovič', 'job_title', 'European Commission vice president']"}
# {'instruction': "Given the subject entity 'Šefčovič', extract the full triple from the sentence.", 'input': 'The EU and UK are set for an intense round of negotiations in the coming weeks after European Commission vice president Maroš Šefčovič unveiled a range of proposals aimed at cutting the red tape the\xa0Northern Ireland Protocol\xa0has imposed on moving goods from Great Britain to Northern Ireland.', 'output': "['Šefčovič', 'unveil', 'range']"}
# {'instruction': "Given the subject entity 'the Third Way', extract the full triple from the sentence.", 'input': 'The group is believed to support the Third Way, a far-right party with suspected links to neo-Nazi groups.', 'output': "['the Third Way', 'known_as', 'far-right party']"}
# {'instruction': "Given the subject entity 'Fred Enanga', extract the full triple from the sentence.", 'input': 'Police spokesman Fred Enanga said the suspected bombers ordered food and drinks at the bar, before placing the bag under a table. The explosion went off moments after they left.', 'output': "['Fred Enanga', 'job_title', 'police spokesman']"}
# {'instruction': "Given the subject entity 'bombers', extract the full triple from the sentence.", 'input': 'Police spokesman Fred Enanga said the suspected bombers ordered food and drinks at the bar, before placing the bag under a table. The explosion went off moments after they left.', 'output': "['bombers', 'order', 'bar']"}
# {'instruction': "Given the subject entity 'Damian Lillard', extract the full triple from the sentence.", 'input': 'Last year, Damian Lillard was an All-Star and averaged 28.8 points, 4.2 rebounds and 7.5 assists per game. ', 'output': "['Damian Lillard', 'known_as', 'All-Star']"}
# {'instruction': "Given the subject entity 'Chauncey Billups', extract the full triple from the sentence.", 'input': 'With controversy surrounding Damian Lillard’s future and \nrookie head coach Chauncey Billups’ alleged off-court indiscretions, the franchise and fanbase have dealt with more than their regular dose of negative summer speculation.', 'output': "['Chauncey Billups', 'job_title', 'rookie head coach']"}
# {'instruction': "Given the subject entity 'controversy', extract the full triple from the sentence.", 'input': 'With controversy surrounding Damian Lillard’s future and \nrookie head coach Chauncey Billups’ alleged off-court indiscretions, the franchise and fanbase have dealt with more than their regular dose of negative summer speculation.', 'output': "['controversy', 'allege', 'indiscretions']"}
# {'instruction': "Given the subject entity 'franchise', extract the full triple from the sentence.", 'input': 'With controversy surrounding Damian Lillard’s future and \nrookie head coach Chauncey Billups’ alleged off-court indiscretions, the franchise and fanbase have dealt with more than their regular dose of negative summer speculation.', 'output': "['franchise', 'deal', 'more']"}
# {'instruction': "Given the subject entity 'Robert Wood', extract the full triple from the sentence.", 'input': 'On Monday, US disarmament ambassador Robert Wood said the US was "very concerned", adding that Washington "had held back from pursuing military applications for this technology".', 'output': "['Robert Wood', 'job_title', 'US disarmament ambassador']"}
# {'instruction': "Given the subject entity 'Wood', extract the full triple from the sentence.", 'input': 'On Monday, US disarmament ambassador Robert Wood said the US was "very concerned", adding that Washington "had held back from pursuing military applications for this technology".', 'output': "['Wood', 'say', 'Monday']"}
# {'instruction': "Given the subject entity 'Tsai Ing-wen', extract the full triple from the sentence.", 'input': 'Taiwan President\xa0Tsai Ing-wen\xa0has described the island as\n being on the front lines of a global ideological battle,\xa0writing in Foreign Affairs\xa0this month that “if Taiwan were to fall, the consequences would be catastrophic for regional peace and the democratic alliance system.”', 'output': "['Tsai Ing-wen', 'job_title', 'Taiwan President']"}
# {'instruction': "Given the subject entity 'President', extract the full triple from the sentence.", 'input': 'Taiwan President\xa0Tsai Ing-wen\xa0has described the island as\n being on the front lines of a global ideological battle,\xa0writing in Foreign Affairs\xa0this month that “if Taiwan were to fall, the consequences would be catastrophic for regional peace and the democratic alliance system.”', 'output': "['President', 'describe', 'island']"}
# {'instruction': "Given the subject entity 'Islamic State (IS)', extract the full triple from the sentence.", 'input': "Wednesday's bombing in Damascus was reportedly the deadliest in the city since March 2017, when 31 people were killed in\xa0a suicide attack at the main court complex\xa0that was claimed by the jihadist group Islamic State (IS).", 'output': "['Islamic State (IS)', 'known_as', 'jihadist group']"}
# {'instruction': "Given the subject entity 'The News International', extract the full triple from the sentence.", 'input': 'According to The News International, one of the largest English language newspapers in Pakistan, the country is in the throes of a deep financial crisis – with the Imran Khan-led regime ideally requiring gross external financing of $51.6 billion within a two-year period (2021-2023) in order to fulfill its needs.', 'output': "['The News International', 'known_as', 'one of the largest English language newspapers in Pakistan']"}
# {'instruction': "Given the subject entity 'regime', extract the full triple from the sentence.", 'input': 'According to The News International, one of the largest English language newspapers in Pakistan, the country is in the throes of a deep financial crisis – with the Imran Khan-led regime ideally requiring gross external financing of $51.6 billion within a two-year period (2021-2023) in order to fulfill its needs.', 'output': "['regime', 'require', 'order']"}
# {'instruction': "Given the subject entity 'Rucker Park', extract the full triple from the sentence.", 'input': 'Rucker Park in Harlem is a basketball institution - a court that attracts both neighbourhood players and past and current NBA superstars like Kevin Durant, Kobe Bryant and Michael Jordan.', 'output': "['Rucker Park', 'part_of', 'harlem']"}
# {'instruction': "Given the subject entity 'Kevin Durant', extract the full triple from the sentence.", 'input': 'Rucker Park in Harlem is a basketball institution - a court that attracts both neighbourhood players and past and current NBA superstars like Kevin Durant, Kobe Bryant and Michael Jordan.', 'output': "['Kevin Durant', 'known_as', 'NBA superstar']"}
# {'instruction': "Given the subject entity 'Kobe Bryant', extract the full triple from the sentence.", 'input': 'Rucker Park in Harlem is a basketball institution - a court that attracts both neighbourhood players and past and current NBA superstars like Kevin Durant, Kobe Bryant and Michael Jordan.', 'output': "['Kobe Bryant', 'known_as', 'NBA superstar']"}
# {'instruction': "Given the subject entity 'Michael Jordan', extract the full triple from the sentence.", 'input': 'Rucker Park in Harlem is a basketball institution - a court that attracts both neighbourhood players and past and current NBA superstars like Kevin Durant, Kobe Bryant and Michael Jordan.', 'output': "['Michael Jordan', 'known_as', 'NBA superstar']"}
# {'instruction': "Given the subject entity 'that', extract the full triple from the sentence.", 'input': 'Rucker Park in Harlem is a basketball institution - a court that attracts both neighbourhood players and past and current NBA superstars like Kevin Durant, Kobe Bryant and Michael Jordan.', 'output': "['that', 'attract', 'players']"}
# {'instruction': "Given the subject entity 'Dr Rachel Levine', extract the full triple from the sentence.", 'input': 'Dr Rachel Levine, 63, is now an admiral of the US Public Health Service Commissioned Corps.', 'output': "['Dr Rachel Levine', 'job_title', 'admiral of the US Public Health Service Comissioned Corps']"}
# {'instruction': "Given the subject entity 'Dr Levine', extract the full triple from the sentence.", 'input': 'Dr Levine is a graduate of Harvard College and Tulane University School of Medicine and previously worked as a paediatrician.', 'output': "['Dr Levine', 'graduated_from', 'Harvard College']"}
# {'instruction': "Given the subject entity 'Dr Levine', extract the full triple from the sentence.", 'input': 'Dr Levine is a graduate of Harvard College and Tulane University School of Medicine and previously worked as a paediatrician.', 'output': "['Dr Levine', 'graduated_from', 'Tulane University School of Medicine']"}
# {'instruction': "Given the subject entity 'Dr Levine', extract the full triple from the sentence.", 'input': 'Dr Levine is a graduate of Harvard College and Tulane University School of Medicine and previously worked as a paediatrician.', 'output': "['Dr Levine', 'job_title', 'paediatrician']"}
# {'instruction': "Given the subject entity 'Charles de Gaulle airport', extract the full triple from the sentence.", 'input': 'Once in the transit zone of Charles de Gaulle airport in Paris, he sought help from the police.', 'output': "['Charles de Gaulle airport', 'located_in', 'Paris']"}
# {'instruction': "Given the subject entity 'he', extract the full triple from the sentence.", 'input': 'Once in the transit zone of Charles de Gaulle airport in Paris, he sought help from the police.', 'output': "['he', 'seek', 'help']"}
# {'instruction': "Given the subject entity 'Society for Historic Swordsmanship', extract the full triple from the sentence.", 'input': 'Mr Toebbe had an interest in medieval weaponry and was active in a local chapter of an enthusiast organisation, the Society for Historic Swordsmanship.', 'output': "['Society for Historic Swordsmanship', 'known_as', 'enthusiast organisation']"}
# {'instruction': "Given the subject entity 'Toebbe', extract the full triple from the sentence.", 'input': 'Mr Toebbe had an interest in medieval weaponry and was active in a local chapter of an enthusiast organisation, the Society for Historic Swordsmanship.', 'output': "['Toebbe', 'have', 'interest']"}
# {'instruction': "Given the subject entity 'David Charney', extract the full triple from the sentence.", 'input': 'It is a bit of a mystery, said David Charney, an Alexandria, Virginia-based psychiatrist who has spent decades studying espionage cases.\xa0', 'output': "['David Charney', 'job_title', 'psychiatrist']"}
# {'instruction': "Given the subject entity 'who', extract the full triple from the sentence.", 'input': 'It is a bit of a mystery, said David Charney, an Alexandria, Virginia-based psychiatrist who has spent decades studying espionage cases.\xa0', 'output': "['who', 'spend', 'decades']"}
# {'instruction': "Given the subject entity 'Edward MacMahon', extract the full triple from the sentence.", 'input': 'She is now represent by two lawyers, Edward MacMahon of Middleburg, Virginia, and Barry Beck of Martinsburg.', 'output': "['Edward MacMahon', 'job_title', 'lawyer']"}
# {'instruction': "Given the subject entity 'Barry Beck', extract the full triple from the sentence.", 'input': 'She is now represent by two lawyers, Edward MacMahon of Middleburg, Virginia, and Barry Beck of Martinsburg.', 'output': "['Barry Beck', 'job_title', 'lawyer']"}
# {'instruction': "Given the subject entity 'company', extract the full triple from the sentence.", 'input': 'She applied for a role at a New York-based company and had an interview which went “perfectly”, she says.', 'output': "['company', 'located_in', 'New York']"}
# {'instruction': "Given the subject entity 'She', extract the full triple from the sentence.", 'input': 'She applied for a role at a New York-based company and had an interview which went “perfectly”, she says.', 'output': "['She', 'apply', 'role']"}
# {'instruction': "Given the subject entity 'Lauren Rivera', extract the full triple from the sentence.", 'input': 'During a study of hiring practices in elite banks and other service firms, Northwestern University management professor Lauren Rivera found that\xa0interviewers would look to their own backgrounds and experience\xa0to determine what predicts good performance, then discount candidates who didn’t share those same qualities.', 'output': "['Lauren Rivera', 'job_title', 'Northwestern University management professor']"}
# {'instruction': "Given the subject entity 'Rivera', extract the full triple from the sentence.", 'input': 'During a study of hiring practices in elite banks and other service firms, Northwestern University management professor Lauren Rivera found that\xa0interviewers would look to their own backgrounds and experience\xa0to determine what predicts good performance, then discount candidates who didn’t share those same qualities.', 'output': "['Rivera', 'find', 'study']"}
# {'instruction': "Given the subject entity 'interviewers', extract the full triple from the sentence.", 'input': 'During a study of hiring practices in elite banks and other service firms, Northwestern University management professor Lauren Rivera found that\xa0interviewers would look to their own backgrounds and experience\xa0to determine what predicts good performance, then discount candidates who didn’t share those same qualities.', 'output': "['interviewers', 'look', 'backgrounds']"}
# {'instruction': "Given the subject entity 'what', extract the full triple from the sentence.", 'input': 'During a study of hiring practices in elite banks and other service firms, Northwestern University management professor Lauren Rivera found that\xa0interviewers would look to their own backgrounds and experience\xa0to determine what predicts good performance, then discount candidates who didn’t share those same qualities.', 'output': "['what', 'predict', 'performance']"}
# {'instruction': "Given the subject entity 'who', extract the full triple from the sentence.", 'input': 'During a study of hiring practices in elite banks and other service firms, Northwestern University management professor Lauren Rivera found that\xa0interviewers would look to their own backgrounds and experience\xa0to determine what predicts good performance, then discount candidates who didn’t share those same qualities.', 'output': "['who', 'share', 'qualities']"}
# {'instruction': "Given the subject entity 'Patty McCord', extract the full triple from the sentence.", 'input': '“It’s not about liking each other,” says HR consultant and ex-Netflix chief talent officer Patty McCord.', 'output': "['Patty McCord', 'job_title', 'ex-Netflix chief talent officer']"}
# {'instruction': "Given the subject entity 'Patty McCord', extract the full triple from the sentence.", 'input': '“It’s not about liking each other,” says HR consultant and ex-Netflix chief talent officer Patty McCord.', 'output': "['Patty McCord', 'job_title', 'HR consultant']"}
# {'instruction': "Given the subject entity 'Gustavo Razzetti', extract the full triple from the sentence.", 'input': 'Gustavo Razzetti, Chicago-based CEO of consultancy Fearless Culture, saw this happen when he was working with a tyre manufacturing company', 'output': "['Gustavo Razzetti', 'job_title', 'CEO of consultancy']"}
# {'instruction': "Given the subject entity 'Fearless Culture', extract the full triple from the sentence.", 'input': 'Gustavo Razzetti, Chicago-based CEO of consultancy Fearless Culture, saw this happen when he was working with a tyre manufacturing company', 'output': "['Fearless Culture', 'located_in', 'Chicago']"}
# {'instruction': "Given the subject entity 'he', extract the full triple from the sentence.", 'input': 'Gustavo Razzetti, Chicago-based CEO of consultancy Fearless Culture, saw this happen when he was working with a tyre manufacturing company', 'output': "['he', 'work', 'company']"}
# {'instruction': "Given the subject entity 'Khadar Ahmend', extract the full triple from the sentence.", 'input': " The Gravedigger's Wife, written and directed by Finish-Somali director Khadar Ahmed, beat off competition at Fespaco from 16 other movies.", 'output': "['Khadar Ahmend', 'known_as', 'Finish-Somali director']"}
# {'instruction': "Given the subject entity 'Wife', extract the full triple from the sentence.", 'input': " The Gravedigger's Wife, written and directed by Finish-Somali director Khadar Ahmed, beat off competition at Fespaco from 16 other movies.", 'output': "['Wife', 'beat', 'movies']"}
# {'instruction': "Given the subject entity 'he', extract the full triple from the sentence.", 'input': 'He was born in Somalia but moved to Finland as a teenager.', 'output': "['he', 'place_of_birth', 'Somalia']"}
# {'instruction': "Given the subject entity 'Antweiler', extract the full triple from the sentence.", 'input': ' Three months after this\xa0summer’s catastrophic floods\xa0in Germany’s Ahrweiler region, there are\xa0reminders everywhere\xa0of the destruction they wrought.', 'output': "['Antweiler', 'region_of', 'Germany']"}
# {'instruction': "Given the subject entity 'Florian Trummer', extract the full triple from the sentence.", 'input': 'Its prominence in the election was no surprise to architect Florian Trummer, 65, whose hometown of Antweiler was hit by the floods. ', 'output': "['Florian Trummer', 'job_title', 'architect']"}
# {'instruction': "Given the subject entity 'Florian Trummer', extract the full triple from the sentence.", 'input': 'Its prominence in the election was no surprise to architect Florian Trummer, 65, whose hometown of Antweiler was hit by the floods. ', 'output': "['Florian Trummer', 'age', '65']"}
# {'instruction': "Given the subject entity 'Greta Thunberg', extract the full triple from the sentence.", 'input': 'The issue also spurred tens of thousands of Germans to gather days before the election at a climate action protest outside parliament in Berlin featuring the famed young Swedish activist\xa0Greta Thunberg.', 'output': "['Greta Thunberg', 'known_as', 'young Swedish activist']"}
# {'instruction': "Given the subject entity 'Berlin', extract the full triple from the sentence.", 'input': 'The issue also spurred tens of thousands of Germans to gather days before the election at a climate action protest outside parliament in Berlin featuring the famed young Swedish activist\xa0Greta Thunberg.', 'output': "['Berlin', 'capital_of', 'German']"}
# {'instruction': "Given the subject entity 'issue', extract the full triple from the sentence.", 'input': 'The issue also spurred tens of thousands of Germans to gather days before the election at a climate action protest outside parliament in Berlin featuring the famed young Swedish activist\xa0Greta Thunberg.', 'output': "['issue', 'spur', 'thousands']"}
# {'instruction': "Given the subject entity 'Andreas Goldhau', extract the full triple from the sentence.", 'input': 'The difference in the urgency to\xa0fight climate change\xa0felt by the American and the German electorates comes as a result of decades of environmental messaging in Europe, according to Andreas Goldthau, a research leader at the Institute for Advanced Sustainability Studies in Potsdam, Germany.', 'output': "['Andreas Goldhau', 'known_as', 'research leader']"}
# {'instruction': "Given the subject entity 'Institute for Advanced Sustainability Studies', extract the full triple from the sentence.", 'input': 'The difference in the urgency to\xa0fight climate change\xa0felt by the American and the German electorates comes as a result of decades of environmental messaging in Europe, according to Andreas Goldthau, a research leader at the Institute for Advanced Sustainability Studies in Potsdam, Germany.', 'output': "['Institute for Advanced Sustainability Studies', 'located_in', 'Potsdam']"}
# {'instruction': "Given the subject entity 'Potsdam', extract the full triple from the sentence.", 'input': 'The difference in the urgency to\xa0fight climate change\xa0felt by the American and the German electorates comes as a result of decades of environmental messaging in Europe, according to Andreas Goldthau, a research leader at the Institute for Advanced Sustainability Studies in Potsdam, Germany.', 'output': "['Potsdam', 'city_of', 'Germany']"}
# {'instruction': "Given the subject entity 'Ahr Wine', extract the full triple from the sentence.", 'input': 'The flood’s damage to the region’s wine industry alone is estimated at $175 million, according to the Ahr Wine umbrella organization for winemakers.', 'output': "['Ahr Wine', 'known_as', 'umbrella organization for winemakers']"}
# {'instruction': "Given the subject entity 'Kantar', extract the full triple from the sentence.", 'input': 'A study published last month by the market research company Kantar showed that the number of shoppers polled in Germany who made changes to be more sustainable in the last year was up nearly 9 percent, compared to just over 1 percent of those polled in the U.S.', 'output': "['Kantar', 'known_as', 'market research company']"}
# {'instruction': "Given the subject entity 'Alisal Fire burn area', extract the full triple from the sentence.", 'input': 'Santa Barbara County officials upgraded the recent evacuation warning to an\xa0evacuation order\xa0for parts of the Alisal Fire burn area.', 'output': "['Alisal Fire burn area', 'part_of', 'Santa Barbara County']"}
# {'instruction': "Given the subject entity 'officials', extract the full triple from the sentence.", 'input': 'Santa Barbara County officials upgraded the recent evacuation warning to an\xa0evacuation order\xa0for parts of the Alisal Fire burn area.', 'output': "['officials', 'upgrade', 'evacuation']"}
# {'instruction': "Given the subject entity 'Nation Weather Service office', extract the full triple from the sentence.", 'input': 'Several feet of snow are forecast for the Sierra Nevada mountain range creating nearly impossible driving conditions, according to the National Weather Service (NWS) office in Hanford, California.', 'output': "['Nation Weather Service office', 'located_in', 'Hanford']"}
# {'instruction': "Given the subject entity 'Hanford', extract the full triple from the sentence.", 'input': 'Several feet of snow are forecast for the Sierra Nevada mountain range creating nearly impossible driving conditions, according to the National Weather Service (NWS) office in Hanford, California.', 'output': "['Hanford', 'city', 'California']"}
# {'instruction': "Given the subject entity 'Carolinas', extract the full triple from the sentence.", 'input': 'A temperature battleground is setting the stage for an outbreak that will begin Sunday across the mid Mississippi Valley and move east to the Carolinas and mid-Atlantic states by Monday.', 'output': "['Carolinas', 'state_of', 'mid-Atlantic']"}
# {'instruction': "Given the subject entity 'battleground', extract the full triple from the sentence.", 'input': 'A temperature battleground is setting the stage for an outbreak that will begin Sunday across the mid Mississippi Valley and move east to the Carolinas and mid-Atlantic states by Monday.', 'output': "['battleground', 'set', 'outbreak']"}
# {'instruction': "Given the subject entity 'that', extract the full triple from the sentence.", 'input': 'A temperature battleground is setting the stage for an outbreak that will begin Sunday across the mid Mississippi Valley and move east to the Carolinas and mid-Atlantic states by Monday.', 'output': "['that', 'begin', 'Valley']"}
# {'instruction': "Given the subject entity 'Dave Halls', extract the full triple from the sentence.", 'input': 'The complaints against assistant director Dave Halls include a disregard for\xa0safety protocols\xa0for weapons and pyrotechnics use, blocked fire lanes and exits, and instances of inappropriately sexual behavior in the workplace.', 'output': "['Dave Halls', 'job_title', 'assistant director']"}
# {'instruction': "Given the subject entity 'complaints', extract the full triple from the sentence.", 'input': 'The complaints against assistant director Dave Halls include a disregard for\xa0safety protocols\xa0for weapons and pyrotechnics use, blocked fire lanes and exits, and instances of inappropriately sexual behavior in the workplace.', 'output': "['complaints', 'include', 'disregard']"}
# {'instruction': "Given the subject entity 'Maggie Goll', extract the full triple from the sentence.", 'input': 'Maggie Goll, an IATSE Local 44 prop maker and licensed pyrotechnician, said in a statement to CNN that while working on Hulu\'s "Into the Dark" Anthology Series in February and May of 2019, Halls neglected to hold safety meetings and consistently failed to announce the presence of a firearm on set to the crew, as is protocol.', 'output': "['Maggie Goll', 'job_title', 'IATSE Local 44 prop maker']"}
# {'instruction': "Given the subject entity 'Maggie Goll', extract the full triple from the sentence.", 'input': 'Maggie Goll, an IATSE Local 44 prop maker and licensed pyrotechnician, said in a statement to CNN that while working on Hulu\'s "Into the Dark" Anthology Series in February and May of 2019, Halls neglected to hold safety meetings and consistently failed to announce the presence of a firearm on set to the crew, as is protocol.', 'output': "['Maggie Goll', 'job_title', 'pyrotechnician']"}
# {'instruction': "Given the subject entity 'Goll', extract the full triple from the sentence.", 'input': 'Maggie Goll, an IATSE Local 44 prop maker and licensed pyrotechnician, said in a statement to CNN that while working on Hulu\'s "Into the Dark" Anthology Series in February and May of 2019, Halls neglected to hold safety meetings and consistently failed to announce the presence of a firearm on set to the crew, as is protocol.', 'output': "['Goll', 'say', 'statement']"}
# {'instruction': "Given the subject entity 'Halls', extract the full triple from the sentence.", 'input': 'Maggie Goll, an IATSE Local 44 prop maker and licensed pyrotechnician, said in a statement to CNN that while working on Hulu\'s "Into the Dark" Anthology Series in February and May of 2019, Halls neglected to hold safety meetings and consistently failed to announce the presence of a firearm on set to the crew, as is protocol.', 'output': "['Halls', 'neglect', 'Series']"}
# {'instruction': "Given the subject entity 'officials', extract the full triple from the sentence.", 'input': 'Thai officials say migrant laborers had been trying to make the gloves look new again, when Thai health authorities raided the facility in December.', 'output': "['officials', 'represent', 'Thai']"}
# {'instruction': "Given the subject entity 'authorities', extract the full triple from the sentence.", 'input': 'Thai officials say migrant laborers had been trying to make the gloves look new again, when Thai health authorities raided the facility in December.', 'output': "['authorities', 'raid', 'December']"}
# {'instruction': "Given the subject entity 'Customs and Border Protection', extract the full triple from the sentence.", 'input': 'In February and March this year one US company warned two federal agencies -- Customs and Border Protection and the Food and Drug Administration -- that it had received shipments filled with substandard and visibly soiled gloves from one company in Thailand.', 'output': "['Customs and Border Protection', 'known_as', 'federal agencies']"}
# {'instruction': "Given the subject entity 'Food and Drug Administration', extract the full triple from the sentence.", 'input': 'In February and March this year one US company warned two federal agencies -- Customs and Border Protection and the Food and Drug Administration -- that it had received shipments filled with substandard and visibly soiled gloves from one company in Thailand.', 'output': "['Food and Drug Administration', 'known_as', 'federal agencies']"}
# {'instruction': "Given the subject entity 'company', extract the full triple from the sentence.", 'input': 'In February and March this year one US company warned two federal agencies -- Customs and Border Protection and the Food and Drug Administration -- that it had received shipments filled with substandard and visibly soiled gloves from one company in Thailand.', 'output': "['company', 'warn', 'agencies']"}
# {'instruction': "Given the subject entity 'it', extract the full triple from the sentence.", 'input': 'In February and March this year one US company warned two federal agencies -- Customs and Border Protection and the Food and Drug Administration -- that it had received shipments filled with substandard and visibly soiled gloves from one company in Thailand.', 'output': "['it', 'receive', 'company']"}
# {'instruction': "Given the subject entity 'Tarek Kirschen', extract the full triple from the sentence.", 'input': 'Late last year Tarek Kirschen, a Miami-based businessman, ordered about $2 million of gloves from a Thai-based company called Paddy the Room, which he then sold to a US distributor.', 'output': "['Tarek Kirschen', 'known_as', 'businessman']"}
# {'instruction': "Given the subject entity 'Paddy the Room', extract the full triple from the sentence.", 'input': 'Late last year Tarek Kirschen, a Miami-based businessman, ordered about $2 million of gloves from a Thai-based company called Paddy the Room, which he then sold to a US distributor.', 'output': "['Paddy the Room', 'located_in', 'Thai']"}
# {'instruction': "Given the subject entity 'Kirschen', extract the full triple from the sentence.", 'input': 'Late last year Tarek Kirschen, a Miami-based businessman, ordered about $2 million of gloves from a Thai-based company called Paddy the Room, which he then sold to a US distributor.', 'output': "['Kirschen', 'order', 'company']"}
# {'instruction': "Given the subject entity 'he', extract the full triple from the sentence.", 'input': 'Late last year Tarek Kirschen, a Miami-based businessman, ordered about $2 million of gloves from a Thai-based company called Paddy the Room, which he then sold to a US distributor.', 'output': "['he', 'sell', 'distributor']"}
# {'instruction': "Given the subject entity 'US Liberty LLC', extract the full triple from the sentence.", 'input': 'The other company, US Liberty LLC had a very similar experience with Paddy the Room.', 'output': "['US Liberty LLC', 'located_in', 'US']"}
# {'instruction': "Given the subject entity 'company', extract the full triple from the sentence.", 'input': 'The other company, US Liberty LLC had a very similar experience with Paddy the Room.', 'output': "['company', 'have', 'experience']"}
# {'instruction': "Given the subject entity 'LLC', extract the full triple from the sentence.", 'input': 'The other company, US Liberty LLC had a very similar experience with Paddy the Room.', 'output': "['LLC', 'have', 'experience']"}
# {'instruction': "Given the subject entity 'Firas Jarrar', extract the full triple from the sentence.", 'input': 'It says it was also bilked by a different Vietnemese company which sent them "gloves with holes, with stains, ripped, and in different shades and colours," company President Firas Jarrar told CNN.', 'output': "['Firas Jarrar', 'president', 'company']"}
# {'instruction': "Given the subject entity 'which', extract the full triple from the sentence.", 'input': 'It says it was also bilked by a different Vietnemese company which sent them "gloves with holes, with stains, ripped, and in different shades and colours," company President Firas Jarrar told CNN.', 'output': "['which', 'send', 'gloves']"}
# {'instruction': "Given the subject entity 'Jarrar', extract the full triple from the sentence.", 'input': 'It says it was also bilked by a different Vietnemese company which sent them "gloves with holes, with stains, ripped, and in different shades and colours," company President Firas Jarrar told CNN.', 'output': "['Jarrar', 'tell', 'CNN']"}
# {'instruction': "Given the subject entity 'Naruhito', extract the full triple from the sentence.", 'input': "Princess Mako, niece to Japan's enthroned emperor, Naruhito, is planning to leave the imperial family, moving out of her family's estate on Oct. 26 when her marriage to Fordham-educated Kei Komuro is officially registered.", 'output': "['Naruhito', 'known_as', 'enthroned emperor']"}
# {'instruction': "Given the subject entity 'Kei Komuro', extract the full triple from the sentence.", 'input': "Princess Mako, niece to Japan's enthroned emperor, Naruhito, is planning to leave the imperial family, moving out of her family's estate on Oct. 26 when her marriage to Fordham-educated Kei Komuro is officially registered.", 'output': "['Kei Komuro', 'student_of', 'Fordham']"}
# {'instruction': "Given the subject entity 'Naruhito', extract the full triple from the sentence.", 'input': 'In 2019, the aging but popular Emperor Akihito abdicated, citing his age and declining health. His son, Naruhito, assumed the throne to reserved fanfare.', 'output': "['Naruhito', 'son_of', 'Emperor Akihito']"}
# {'instruction': "Given the subject entity 'aging', extract the full triple from the sentence.", 'input': 'In 2019, the aging but popular Emperor Akihito abdicated, citing his age and declining health. His son, Naruhito, assumed the throne to reserved fanfare.', 'output': "['aging', 'abdicate', '2019']"}
# {'instruction': "Given the subject entity 'son', extract the full triple from the sentence.", 'input': 'In 2019, the aging but popular Emperor Akihito abdicated, citing his age and declining health. His son, Naruhito, assumed the throne to reserved fanfare.', 'output': "['son', 'assume', 'fanfare']"}
# {'instruction': "Given the subject entity 'Naotaka Kimizuka', extract the full triple from the sentence.", 'input': 'Naotaka Kimizuka, professor_of, modern British and European political diplomatic history', 'output': "['Naotaka Kimizuka', 'professor_of', 'Kanto Gakuin University']"}
# {'instruction': "Given the subject entity 'Naotaka Kimizuka', extract the full triple from the sentence.", 'input': 'Naotaka Kimizuka, professor_of, modern British and European political diplomatic history', 'output': "['Naotaka Kimizuka', 'professor_of', 'modern British and European political diplomatic history']"}
# {'instruction': "Given the subject entity 'Hirokazu Matsuno', extract the full triple from the sentence.", 'input': 'Hirokazu Matsuno, a government spokesperson, said in response to the question of dwindling numbers among Japanese royals: "The marriage of Princess Mako is scheduled for the 26th of this month', 'output': "['Hirokazu Matsuno', 'job_title', 'government spokesperson']"}
# {'instruction': "Given the subject entity 'Matsuno', extract the full triple from the sentence.", 'input': 'Hirokazu Matsuno, a government spokesperson, said in response to the question of dwindling numbers among Japanese royals: "The marriage of Princess Mako is scheduled for the 26th of this month', 'output': "['Matsuno', 'say', 'response']"}
# {'instruction': "Given the subject entity 'Fumio Kishida', extract the full triple from the sentence.", 'input': 'Most conservatives, including Prime Minister Fumio Kishida, disagree.\xa0', 'output': "['Fumio Kishida', 'job_title', 'Prime Minister']"}
# {'instruction': "Given the subject entity 'Kazuko Ito', extract the full triple from the sentence.", 'input': 'Attorney Kazuko Ito, secretary general of Human Rights Now, said she believes living human beings can never be a symbol.', 'output': "['Kazuko Ito', 'leader_of', 'Human Rights Now']"}
# {'instruction': "Given the subject entity 'Kazuko Ito', extract the full triple from the sentence.", 'input': 'Attorney Kazuko Ito, secretary general of Human Rights Now, said she believes living human beings can never be a symbol.', 'output': "['Kazuko Ito', 'job_title', 'secretary general']"}
# {'instruction': "Given the subject entity 'Hideya Kawanishi', extract the full triple from the sentence.", 'input': 'Hideya Kawanishi, an associate professor of Japanese history at Nagoya University, believes that keeping together the imperial family helps keep together Japan.', 'output': "['Hideya Kawanishi', 'professor_of', 'Nagoya University']"}
# {'instruction': "Given the subject entity 'Curry', extract the full triple from the sentence.", 'input': 'For a player that has cemented himself as the NBA’s best shooter of all time, Curry often shot the ball as if he knew it would drop into the basket.', 'output': '[\'Curry\', \'known_as\', "NBA\'s best shooter of all time"]'}
# {'instruction': "Given the subject entity 'that', extract the full triple from the sentence.", 'input': 'For a player that has cemented himself as the NBA’s best shooter of all time, Curry often shot the ball as if he knew it would drop into the basket.', 'output': "['that', 'cement', 'shooter']"}
# {'instruction': "Given the subject entity 'Curry', extract the full triple from the sentence.", 'input': 'For a player that has cemented himself as the NBA’s best shooter of all time, Curry often shot the ball as if he knew it would drop into the basket.', 'output': "['Curry', 'shoot', 'ball']"}
# {'instruction': "Given the subject entity 'it', extract the full triple from the sentence.", 'input': 'For a player that has cemented himself as the NBA’s best shooter of all time, Curry often shot the ball as if he knew it would drop into the basket.', 'output': "['it', 'drop', 'basket']"}
# {'instruction': "Given the subject entity 'Brandon Payne', extract the full triple from the sentence.", 'input': 'But Curry and his trainer, Brandon Payne, detailed to NBA.com a new wrinkle in Curry’s training regimen last summer.', 'output': "['Brandon Payne', 'job_title', 'trainer']"}
# {'instruction': "Given the subject entity 'Brandon Payne', extract the full triple from the sentence.", 'input': 'But Curry and his trainer, Brandon Payne, detailed to NBA.com a new wrinkle in Curry’s training regimen last summer.', 'output': "['Brandon Payne', 'assistant_of', 'Curry']"}
# {'instruction': "Given the subject entity 'Curry', extract the full triple from the sentence.", 'input': 'But Curry and his trainer, Brandon Payne, detailed to NBA.com a new wrinkle in Curry’s training regimen last summer.', 'output': "['Curry', 'detail', 'wrinkle']"}
# {'instruction': "Given the subject entity 'Bruce Fraser', extract the full triple from the sentence.", 'input': 'Similar exchanges have happened when Curry has completed offseason and regular-season workouts with Warriors assistant coach Bruce Fraser', 'output': "['Bruce Fraser', 'job_title', 'Warriors assistant coach']"}
# {'instruction': "Given the subject entity 'Curry', extract the full triple from the sentence.", 'input': 'Similar exchanges have happened when Curry has completed offseason and regular-season workouts with Warriors assistant coach Bruce Fraser', 'output': "['Curry', 'complete', 'workouts']"}
# {'instruction': "Given the subject entity 'Steve Kerr', extract the full triple from the sentence.", 'input': 'Therefore, Warriors coach Steve Kerr expressed amusement over Curry describing his first regular-season game as “trash” despite finishing with a triple-double in points (21), assists (10) and rebounds (10).', 'output': "['Steve Kerr', 'leader_of', 'Warriors']"}
# {'instruction': "Given the subject entity 'Kerr', extract the full triple from the sentence.", 'input': 'Therefore, Warriors coach Steve Kerr expressed amusement over Curry describing his first regular-season game as “trash” despite finishing with a triple-double in points (21), assists (10) and rebounds (10).', 'output': "['Kerr', 'express', 'amusement']"}
# {'instruction': "Given the subject entity 'Andre Iguodala', extract the full triple from the sentence.", 'input': '\xa0A summer after the Warriors lost a key star to free agency, (Kevin Durant), a key star to injury (Klay Thompson) and key veteran in a trade (Andre Iguodala), Curry played in only five games in 2019-20 because of a broken left hand and the Warriors finished with the NBA’s worst record (15-50).', 'output': "['Andre Iguodala', 'known_as', 'key veteran']"}
# {'instruction': "Given the subject entity 'Klay Thompson', extract the full triple from the sentence.", 'input': '\xa0A summer after the Warriors lost a key star to free agency, (Kevin Durant), a key star to injury (Klay Thompson) and key veteran in a trade (Andre Iguodala), Curry played in only five games in 2019-20 because of a broken left hand and the Warriors finished with the NBA’s worst record (15-50).', 'output': "['Klay Thompson', 'known_as', 'key star']"}
# {'instruction': "Given the subject entity 'Warriors', extract the full triple from the sentence.", 'input': '\xa0A summer after the Warriors lost a key star to free agency, (Kevin Durant), a key star to injury (Klay Thompson) and key veteran in a trade (Andre Iguodala), Curry played in only five games in 2019-20 because of a broken left hand and the Warriors finished with the NBA’s worst record (15-50).', 'output': "['Warriors', 'lose', 'Durant']"}
# {'instruction': "Given the subject entity 'Curry', extract the full triple from the sentence.", 'input': '\xa0A summer after the Warriors lost a key star to free agency, (Kevin Durant), a key star to injury (Klay Thompson) and key veteran in a trade (Andre Iguodala), Curry played in only five games in 2019-20 because of a broken left hand and the Warriors finished with the NBA’s worst record (15-50).', 'output': "['Curry', 'play', 'hand']"}
# {'instruction': "Given the subject entity 'Warriors', extract the full triple from the sentence.", 'input': '\xa0A summer after the Warriors lost a key star to free agency, (Kevin Durant), a key star to injury (Klay Thompson) and key veteran in a trade (Andre Iguodala), Curry played in only five games in 2019-20 because of a broken left hand and the Warriors finished with the NBA’s worst record (15-50).', 'output': "['Warriors', 'finish', 'record']"}
# ...
# {'instruction': "Given the subject entity 'Mohamed Salah', extract the full triple from the sentence.", 'input': 'Liverpool and Egypt forward Mohamed Salah, 29, wants a £500,000-a-week contract to stay with the Reds', 'output': "['Mohamed Salah', 'member_of', 'Liverpool']"}
# {'instruction': "Given the subject entity 'Liverpool', extract the full triple from the sentence.", 'input': 'Liverpool and Egypt forward Mohamed Salah, 29, wants a £500,000-a-week contract to stay with the Reds', 'output': "['Liverpool', 'want', 'contract']"}
# {'instruction': "Given the subject entity 'Donny van de Beek', extract the full triple from the sentence.", 'input': 'Netherlands midfielder Donny van de Beek has decided to change his agent as he seeks to leave Manchester United this winter, with Everton, Newcastle and Juventus interested in the 24-year-old.', 'output': "['Donny van de Beek', 'place_of_birth', 'Netherlands']"}
# {'instruction': "Given the subject entity 'Zinedine Zidane', extract the full triple from the sentence.", 'input': 'Frenchman Zinedine Zidane is not keen on the top job at Old Trafford despite being out of work after leaving Real Madrid in May', 'output': "['Zinedine Zidane', 'place_of_birth', 'France']"}
# {'instruction': "Given the subject entity 'Donald Trump', extract the full triple from the sentence.", 'input': 'Former United States President Donald Trump has announced the launch of his own social media platform, nine months after being expelled from all major sites for his role in allegedly inciting violence at the US Capitol following his election defeat last year.', 'output': "['Donald Trump', 'president_of', 'United States']"}
# {'instruction': "Given the subject entity 'Trump', extract the full triple from the sentence.", 'input': 'Former United States President Donald Trump has announced the launch of his own social media platform, nine months after being expelled from all major sites for his role in allegedly inciting violence at the US Capitol following his election defeat last year.', 'output': "['Trump', 'announce', 'launch']"}
# {'instruction': "Given the subject entity 'Achraf Hakimi', extract the full triple from the sentence.", 'input': 'Both sides had goals ruled out by the video assistant referee (VAR) - and PSG had Achraf Hakimi sent off for a professional foul on Cengiz Under.', 'output': "['Achraf Hakimi', 'member_of', 'PSG']"}
# {'instruction': "Given the subject entity 'Hakimi', extract the full triple from the sentence.", 'input': 'Both sides had goals ruled out by the video assistant referee (VAR) - and PSG had Achraf Hakimi sent off for a professional foul on Cengiz Under.', 'output': "['Hakimi', 'send', 'foul']"}
# {'instruction': "Given the subject entity 'Arkadiusz Milik', extract the full triple from the sentence.", 'input': "A Luan Peres own goal from Neymar's cross and Arkadiusz Milik's strike for Marseille in the first half were both ruled out by the VAR for offside.", 'output': "['Arkadiusz Milik', 'member_of', 'Marseille']"}
# {'instruction': "Given the subject entity 'Peres', extract the full triple from the sentence.", 'input': "A Luan Peres own goal from Neymar's cross and Arkadiusz Milik's strike for Marseille in the first half were both ruled out by the VAR for offside.", 'output': "['Peres', 'own', 'goal']"}
# {'instruction': "Given the subject entity 'University of California', extract the full triple from the sentence.", 'input': 'Billionaire Charlie Munger is bankrolling the design of a massive dormitory at the University of California, Santa Barbara.', 'output': "['University of California', 'located_in', 'Santa Barbara']"}
# {'instruction': "Given the subject entity 'Munger', extract the full triple from the sentence.", 'input': 'Billionaire Charlie Munger is bankrolling the design of a massive dormitory at the University of California, Santa Barbara.', 'output': "['Munger', 'bankroll', 'design']"}
# {'instruction': "Given the subject entity 'Munger', extract the full triple from the sentence.", 'input': "Munger, the 97-year-old vice chairman of Warren Buffet's Berkshire Hathaway, donated $200 million to UCSB to fund the dorms, with the caveat that his designs are followed. ", 'output': "['Munger', 'age', '97']"}
# {'instruction': "Given the subject entity 'Munger', extract the full triple from the sentence.", 'input': "Munger, the 97-year-old vice chairman of Warren Buffet's Berkshire Hathaway, donated $200 million to UCSB to fund the dorms, with the caveat that his designs are followed. ", 'output': "['Munger', 'donate', 'UCSB']"}
# {'instruction': "Given the subject entity 'Elon Musk', extract the full triple from the sentence.", 'input': 'Billionaire Elon Musk, CEO of SpaceX and Tesla, often tweets about different cryptocurrencies, and in doing so, has seemingly impacted their prices.', 'output': "['Elon Musk', 'CEO_of', 'SpaceX']"}
# {'instruction': "Given the subject entity 'Elon Musk', extract the full triple from the sentence.", 'input': 'Billionaire Elon Musk, CEO of SpaceX and Tesla, often tweets about different cryptocurrencies, and in doing so, has seemingly impacted their prices.', 'output': "['Elon Musk', 'CEO_of', 'Tesla']"}
# {'instruction': "Given the subject entity 'Musk', extract the full triple from the sentence.", 'input': 'Billionaire Elon Musk, CEO of SpaceX and Tesla, often tweets about different cryptocurrencies, and in doing so, has seemingly impacted their prices.', 'output': "['Musk', 'tweet', 'cryptocurrencies']"}
# {'instruction': "Given the subject entity 'Aryan Khan', extract the full triple from the sentence.", 'input': 'The first is Aryan Khan, the 23-year-old son of Bollywood superstar Shah Rukh Khan, who was arrested on early Sunday morning for allegedly doing recreational drugs at a party.', 'output': "['Aryan Khan', 'son_of', 'Shah Rukh Khan']"}
# {'instruction': "Given the subject entity 'Khan', extract the full triple from the sentence.", 'input': 'Khan, a 41-year-old citizen of Pakistan who came to the U.S. in the 1990s and graduated from high school near Baltimore, earlier pleaded guilty to war crimes charges that included conspiracy and murder for his involvement in al-Qaida plots such as the deadly bombing of the J.W. Marriott hotel in Jakarta, Indonesia, in August 2003.', 'output': "['Khan', 'place_of_birth', 'Pakisthan']"}
# {'instruction': "Given the subject entity 'who', extract the full triple from the sentence.", 'input': 'Khan, a 41-year-old citizen of Pakistan who came to the U.S. in the 1990s and graduated from high school near Baltimore, earlier pleaded guilty to war crimes charges that included conspiracy and murder for his involvement in al-Qaida plots such as the deadly bombing of the J.W. Marriott hotel in Jakarta, Indonesia, in August 2003.', 'output': "['who', 'come', '1990s']"}
# {'instruction': "Given the subject entity 'that', extract the full triple from the sentence.", 'input': 'Khan, a 41-year-old citizen of Pakistan who came to the U.S. in the 1990s and graduated from high school near Baltimore, earlier pleaded guilty to war crimes charges that included conspiracy and murder for his involvement in al-Qaida plots such as the deadly bombing of the J.W. Marriott hotel in Jakarta, Indonesia, in August 2003.', 'output': "['that', 'include', 'August']"}
# {'instruction': "Given the subject entity 'Kim Yo Jong', extract the full triple from the sentence.", 'input': "Kim Yo Jong, sister of North Korea's leader Kim Jong Un, in Hanoi, on March 2, 2019.", 'output': "['Kim Yo Jong', 'sister_of', 'Kun Jong Un']"}
# {'instruction': "Given the subject entity 'Kim Jong Un', extract the full triple from the sentence.", 'input': "Kim Yo Jong, sister of North Korea's leader Kim Jong Un, in Hanoi, on March 2, 2019.", 'output': "['Kim Jong Un', 'leader_of', 'North Korea']"}
# {'instruction': "Given the subject entity 'Marilyn Pfeifer', extract the full triple from the sentence.", 'input': 'Lisowski said her mother Marilyn Pfeifer followed coronavirus precautions and was fully vaccinated', 'output': "['Marilyn Pfeifer', 'mother_of', 'Lisowski']"}
# {'instruction': "Given the subject entity 'mother', extract the full triple from the sentence.", 'input': 'Lisowski said her mother Marilyn Pfeifer followed coronavirus precautions and was fully vaccinated', 'output': "['mother', 'follow', 'precautions']"}
# {'instruction': "Given the subject entity 'British Columbia', extract the full triple from the sentence.", 'input': 'British Columbia will begin offering COVID-19 vaccine booster shots to everyone over the age of 12 from January, officials said on Tuesday, becoming the first major Canadian province to significantly widen eligibility for boosters.', 'output': "['British Columbia', 'province_of', 'Canada']"}
# {'instruction': "Given the subject entity 'officials', extract the full triple from the sentence.", 'input': 'British Columbia will begin offering COVID-19 vaccine booster shots to everyone over the age of 12 from January, officials said on Tuesday, becoming the first major Canadian province to significantly widen eligibility for boosters.', 'output': "['officials', 'say', 'Tuesday']"}
# {'instruction': "Given the subject entity 'Sean Irwin', extract the full triple from the sentence.", 'input': 'Sean Irwin, 36, of Brentwood in Essex, said he bought the ticket on a whim with some spare change.', 'output': "['Sean Irwin', 'age', '26']"}
# {'instruction': "Given the subject entity 'Sean Irwin', extract the full triple from the sentence.", 'input': 'Sean Irwin, 36, of Brentwood in Essex, said he bought the ticket on a whim with some spare change.', 'output': "['Sean Irwin', 'resident_of', 'Brentwood']"}
# {'instruction': "Given the subject entity 'he', extract the full triple from the sentence.", 'input': 'Sean Irwin, 36, of Brentwood in Essex, said he bought the ticket on a whim with some spare change.', 'output': "['he', 'buy', 'change']"}
# {'instruction': "Given the subject entity 'Freddie Freeman', extract the full triple from the sentence.", 'input': 'Hank Aaron Jr. threw out the first pitch, which was caught by Freddie Freeman, the winner of the 2020 Hank Aaron award.', 'output': "['Freddie Freeman', 'winner_of', '2020 Hank Aaron award']"}
# {'instruction': "Given the subject entity 'Jr.', extract the full triple from the sentence.", 'input': 'Hank Aaron Jr. threw out the first pitch, which was caught by Freddie Freeman, the winner of the 2020 Hank Aaron award.', 'output': "['Jr.', 'throw', 'pitch']"}
# {'instruction': "Given the subject entity 'Ejin Banner', extract the full triple from the sentence.", 'input': 'The Ejin Banner is located in the Gobi Desert, next to the Mongolian border.', 'output': "['Ejin Banner', 'located_in', 'Gobi Desert']"}
# {'instruction': "Given the subject entity 'Jeff Bezos', extract the full triple from the sentence.", 'input': 'The mogul is now worth over $100billion more than the second-richest person on earth, Amazon founder Jeff Bezos.', 'output': "['Jeff Bezos', 'founder_of', 'Amazon']"}
# {'instruction': "Given the subject entity 'Penelope Jackson', extract the full triple from the sentence.", 'input': 'Penelope Jackson killed her husband David at their home in Somerset in February', 'output': "['Penelope Jackson', 'spouse', 'David']"}
# {'instruction': "Given the subject entity 'Jackson', extract the full triple from the sentence.", 'input': 'Penelope Jackson killed her husband David at their home in Somerset in February', 'output': "['Jackson', 'kill', 'home']"}
# {'instruction': "Given the subject entity 'Joseph Rosenbaum', extract the full triple from the sentence.", 'input': 'Rittenhouse, 18, was charged with homicide and attempted homicide after he fatally shot Joseph Rosenbaum, 36, and Anthony Huber, 26, and wounded Gaige Grosskreutz in Kenosha during protests that followed the shooting of Jacob Blake, a Black man, by a white police officer.', 'output': "['Joseph Rosenbaum', 'shot_by', 'Rittenhouse']"}
# {'instruction': "Given the subject entity 'Anthony Huber', extract the full triple from the sentence.", 'input': 'Rittenhouse, 18, was charged with homicide and attempted homicide after he fatally shot Joseph Rosenbaum, 36, and Anthony Huber, 26, and wounded Gaige Grosskreutz in Kenosha during protests that followed the shooting of Jacob Blake, a Black man, by a white police officer.', 'output': "['Anthony Huber', 'shot_by', 'Rittenhouse']"}
# {'instruction': "Given the subject entity 'he', extract the full triple from the sentence.", 'input': 'Rittenhouse, 18, was charged with homicide and attempted homicide after he fatally shot Joseph Rosenbaum, 36, and Anthony Huber, 26, and wounded Gaige Grosskreutz in Kenosha during protests that followed the shooting of Jacob Blake, a Black man, by a white police officer.', 'output': "['he', 'shoot', 'Rosenbaum']"}
# {'instruction': "Given the subject entity 'that', extract the full triple from the sentence.", 'input': 'Rittenhouse, 18, was charged with homicide and attempted homicide after he fatally shot Joseph Rosenbaum, 36, and Anthony Huber, 26, and wounded Gaige Grosskreutz in Kenosha during protests that followed the shooting of Jacob Blake, a Black man, by a white police officer.', 'output': "['that', 'follow', 'shooting']"}
# {'instruction': "Given the subject entity 'Novel Price', extract the full triple from the sentence.", 'input': 'After Abdulrazak Gurnah was awarded this year’s Nobel Prize in Literature, he instantly gained a wider international audience, something publishers are now scrambling to accommodate.', 'output': "['Novel Price', 'awarded_for', 'Abdulrazak Gurnah']"}
# {'instruction': "Given the subject entity 'he', extract the full triple from the sentence.", 'input': 'After Abdulrazak Gurnah was awarded this year’s Nobel Prize in Literature, he instantly gained a wider international audience, something publishers are now scrambling to accommodate.', 'output': "['he', 'gain', 'audience']"}
# {'instruction': "Given the subject entity 'In-N-Out Burger', extract the full triple from the sentence.", 'input': 'This comes about two weeks after another In-N-Out Burger located in San Francisco’s Fisherman’s Warf was shut down for allowing indoor dining without checking for proof of vaccination.', 'output': "['In-N-Out Burger', 'located_in', 'Fisherman’s Warf']"}
# {'instruction': "Given the subject entity 'Fisherman’s Warf', extract the full triple from the sentence.", 'input': 'This comes about two weeks after another In-N-Out Burger located in San Francisco’s Fisherman’s Warf was shut down for allowing indoor dining without checking for proof of vaccination.', 'output': "['Fisherman’s Warf', 'region_of', 'San Francisco']"}
# {'instruction': "Given the subject entity 'Edward Ward', extract the full triple from the sentence.", 'input': 'This comes about four months after Edward Ward, a 68-year-old professor at St. Cloud State University, died after being shot in the doorway of his home on the 2600 Block of Island View Drive. ', 'output': "['Edward Ward', 'age', '68']"}
# {'instruction': "Given the subject entity 'Bonnie Fleming', extract the full triple from the sentence.", 'input': '“MicroBooNE has made a very comprehensive exploration through multiple types of interactions, and multiple analysis and reconstruction techniques,” said Bonnie Fleming, physics professor at Yale University and co-spokesperson for MicroBooNE.', 'output': "['Bonnie Fleming', 'professor_of', 'physics']"}
# {'instruction': "Given the subject entity 'MicroBooNE', extract the full triple from the sentence.", 'input': '“MicroBooNE has made a very comprehensive exploration through multiple types of interactions, and multiple analysis and reconstruction techniques,” said Bonnie Fleming, physics professor at Yale University and co-spokesperson for MicroBooNE.', 'output': "['MicroBooNE', 'make', 'types']"}

# %%
new_set_test = build_subject_conditioned_dataset(dataset_test)

# %%
new_set_test
# Out:
# Dataset({
#     features: ['instruction', 'input', 'output'],
#     num_rows: 973
# })

# %%
new_set_test
# Out:
# Dataset({
#     features: ['instruction', 'input', 'output'],
#     num_rows: 973
# })

# %%
new_set_test[0]
# Out:
# {'instruction': "Given the subject entity 'Nashville North', extract the full triple from the sentence.",
#  'input': 'The rarified space is the cavernous outdoor concert location in the middle of the Calgary Stampede grounds that’s known as Nashville North, where people lingering at picnic tables sip Molson Canadian and Budweiser as musicians belt out covers of Tim McGraw and Toby Keith.',
#  'output': "['Nashville North', 'known_as', 'outdoor concert']"}

# %%
new_set_test[1]
# Out:
# {'instruction': "Given the subject entity 'Tim McGraw', extract the full triple from the sentence.",
#  'input': 'The rarified space is the cavernous outdoor concert location in the middle of the Calgary Stampede grounds that’s known as Nashville North, where people lingering at picnic tables sip Molson Canadian and Budweiser as musicians belt out covers of Tim McGraw and Toby Keith.',
#  'output': "['Tim McGraw', 'job_title', 'musician']"}

# %%
new_set_test[2]
# Out:
# {'instruction': "Given the subject entity 'Toby Keith', extract the full triple from the sentence.",
#  'input': 'The rarified space is the cavernous outdoor concert location in the middle of the Calgary Stampede grounds that’s known as Nashville North, where people lingering at picnic tables sip Molson Canadian and Budweiser as musicians belt out covers of Tim McGraw and Toby Keith.',
#  'output': "['Toby Keith', 'job_title', 'musician']"}

# %%
new_set_test[3]
# Out:
# {'instruction': "Given the subject entity 'people', extract the full triple from the sentence.",
#  'input': 'The rarified space is the cavernous outdoor concert location in the middle of the Calgary Stampede grounds that’s known as Nashville North, where people lingering at picnic tables sip Molson Canadian and Budweiser as musicians belt out covers of Tim McGraw and Toby Keith.',
#  'output': "['people', 'sip', 'Canadian']"}

# %%
new_set_test[4]
# Out:
# {'instruction': "Given the subject entity 'musicians', extract the full triple from the sentence.",
#  'input': 'The rarified space is the cavernous outdoor concert location in the middle of the Calgary Stampede grounds that’s known as Nashville North, where people lingering at picnic tables sip Molson Canadian and Budweiser as musicians belt out covers of Tim McGraw and Toby Keith.',
#  'output': "['musicians', 'belt', 'covers']"}

# %%
new_set_test[5]
# Out:
# {'instruction': "Given the subject entity 'Strieck', extract the full triple from the sentence.",
#  'input': 'Strieck moved to Calgary and 1992 and landed at the airport on a Stampede Saturday and fell in love with her new home then and there.',
#  'output': "['Strieck', 'resident_of', 'Calgary']"}

# %%
import spacy
import ast
from datasets import Dataset

# Load spaCy model
nlp = spacy.load("en_core_web_sm")

# Util: Reconstruct compound subject/object
def get_compound_noun(token):
    compound_parts = []
    for child in token.lefts:
        if child.dep_ in ("compound", "amod"):
            compound_parts.append(child.text)
    compound_parts.append(token.text)
    return " ".join(compound_parts)

# Extract full triples with compound nouns
def extract_clean_triples(sentence):
    doc = nlp(sentence)
    triples = []

    for token in doc:
        # Rule 1: subject → verb → object
        if token.dep_ == "nsubj" and token.head.pos_ == "VERB":
            subject = get_compound_noun(token)
            predicate = token.head.lemma_

            obj_token = None
            for child in token.head.children:
                if child.dep_ in ("dobj", "attr", "oprd"):
                    obj_token = child
                elif child.dep_ == "prep":
                    for subchild in child.children:
                        if subchild.dep_ == "pobj":
                            obj_token = subchild

            if obj_token:
                obj = get_compound_noun(obj_token)
                triples.append([subject, predicate, obj])

        # Rule 2: passive (e.g. land claimed by farmers)
        if token.dep_ == "agent" and token.head.dep_ == "acl":
            for child in token.children:
                if child.pos_ in ("NOUN", "PROPN"):
                    subject = get_compound_noun(child)
                    predicate = f"{token.head.lemma_}_by"
                    obj = token.head.head.text
                    triples.append([subject, predicate, obj])

    return triples

# Build dataset with both gold and extracted triples
def build_triple_dataset(dataset):
    examples = []

    for row in dataset:
        sentence = row["input"]

        # 1. Get gold triples (if any)
        try:
            gold_triples = ast.literal_eval(row["output"])
        except:
            gold_triples = []

        gold_set = set(tuple(trip) for trip in gold_triples)

        # Add gold triples
        for subj, pred, obj in gold_triples:
            examples.append({
                "instruction": f"Given the subject entity '{subj}', extract the full triple from the sentence.",
                "input": sentence,
                "output": str([subj, pred, obj])
            })

        # 2. Get extracted triples from spaCy
        extracted_triples = extract_clean_triples(sentence)
        for subj, pred, obj in extracted_triples:
            if (subj, pred, obj) not in gold_set:
                examples.append({
                    "instruction": f"Given the subject entity '{subj}', extract the full triple from the sentence.",
                    "input": sentence,
                    "output": str([subj, pred, obj])
                })

    return Dataset.from_list(examples)

# %%
new_trained = build_triple_dataset(dataset_train)

# %%
new_tested = build_triple_dataset(dataset_test)

# %%
new_tested
# Out:
# Dataset({
#     features: ['instruction', 'input', 'output'],
#     num_rows: 973
# })

# %%
new_tested[0]
# Out:
# {'instruction': "Given the subject entity 'Nashville North', extract the full triple from the sentence.",
#  'input': 'The rarified space is the cavernous outdoor concert location in the middle of the Calgary Stampede grounds that’s known as Nashville North, where people lingering at picnic tables sip Molson Canadian and Budweiser as musicians belt out covers of Tim McGraw and Toby Keith.',
#  'output': "['Nashville North', 'known_as', 'outdoor concert']"}

# %%
new_tested[1]
# Out:
# {'instruction': "Given the subject entity 'Tim McGraw', extract the full triple from the sentence.",
#  'input': 'The rarified space is the cavernous outdoor concert location in the middle of the Calgary Stampede grounds that’s known as Nashville North, where people lingering at picnic tables sip Molson Canadian and Budweiser as musicians belt out covers of Tim McGraw and Toby Keith.',
#  'output': "['Tim McGraw', 'job_title', 'musician']"}

# %%
new_tested[2]
# Out:
# {'instruction': "Given the subject entity 'Toby Keith', extract the full triple from the sentence.",
#  'input': 'The rarified space is the cavernous outdoor concert location in the middle of the Calgary Stampede grounds that’s known as Nashville North, where people lingering at picnic tables sip Molson Canadian and Budweiser as musicians belt out covers of Tim McGraw and Toby Keith.',
#  'output': "['Toby Keith', 'job_title', 'musician']"}

# %%
new_tested[3]
# Out:
# {'instruction': "Given the subject entity 'people', extract the full triple from the sentence.",
#  'input': 'The rarified space is the cavernous outdoor concert location in the middle of the Calgary Stampede grounds that’s known as Nashville North, where people lingering at picnic tables sip Molson Canadian and Budweiser as musicians belt out covers of Tim McGraw and Toby Keith.',
#  'output': "['people', 'sip', 'Molson Canadian']"}

# %%
new_tested[4]
# Out:
# {'instruction': "Given the subject entity 'musicians', extract the full triple from the sentence.",
#  'input': 'The rarified space is the cavernous outdoor concert location in the middle of the Calgary Stampede grounds that’s known as Nashville North, where people lingering at picnic tables sip Molson Canadian and Budweiser as musicians belt out covers of Tim McGraw and Toby Keith.',
#  'output': "['musicians', 'belt', 'covers']"}

# %%
import spacy
import ast
from datasets import Dataset

# Load spaCy model
nlp = spacy.load("en_core_web_sm")

# -------- Utility: Reconstruct compound noun phrases --------
def get_compound_noun(token):
    compound_parts = []
    for child in token.lefts:
        if child.dep_ in ("compound", "amod"):
            compound_parts.append(child.text)
    compound_parts.append(token.text)
    return " ".join(compound_parts)

# -------- Triple Extraction Function (with conjunct handling) --------
def extract_clean_triples(sentence):
    doc = nlp(sentence)
    triples = []

    for token in doc:
        # Rule 1: subject → verb → object
        if token.dep_ == "nsubj" and token.head.pos_ == "VERB":
            subject = get_compound_noun(token)
            predicate = token.head.lemma_

            obj_token = None
            for child in token.head.children:
                if child.dep_ in ("dobj", "attr", "oprd"):
                    obj_token = child
                elif child.dep_ == "prep":
                    for subchild in child.children:
                        if subchild.dep_ == "pobj":
                            obj_token = subchild

            if obj_token:
                obj_main = get_compound_noun(obj_token)
                triples.append([subject, predicate, obj_main])

                # NEW: Handle "conj" objects like "Budweiser"
                for sibling in obj_token.conjuncts:
                    obj_alt = get_compound_noun(sibling)
                    triples.append([subject, predicate, obj_alt])

        # Rule 2: passive voice agent pattern
        if token.dep_ == "agent" and token.head.dep_ == "acl":
            for child in token.children:
                if child.pos_ in ("NOUN", "PROPN"):
                    subject = get_compound_noun(child)
                    predicate = f"{token.head.lemma_}_by"
                    obj = token.head.head.text
                    triples.append([subject, predicate, obj])

    return triples

# -------- Final Dataset Builder: Combine Extracted + Gold Triples --------
def build_combined_triple_dataset(dataset):
    examples = []

    for row in dataset:
        sentence = row["input"]

        # Get gold triples (if available)
        try:
            gold_triples = ast.literal_eval(row["output"])
        except:
            gold_triples = []

        gold_set = set(tuple(trip) for trip in gold_triples)

        # Add gold-labeled triples
        for subj, pred, obj in gold_triples:
            examples.append({
                "instruction": f"Given the subject entity '{subj}', extract the full triple from the sentence.",
                "input": sentence,
                "output": str([subj, pred, obj])
            })

        # Extracted triples using spaCy
        extracted_triples = extract_clean_triples(sentence)
        for subj, pred, obj in extracted_triples:
            if (subj, pred, obj) not in gold_set:
                examples.append({
                    "instruction": f"Given the subject entity '{subj}', extract the full triple from the sentence.",
                    "input": sentence,
                    "output": str([subj, pred, obj])
                })

    return Dataset.from_list(examples)

# %%
new_tested = build_combined_triple_dataset(dataset_test)

# %%
new_tested
# Out:
# Dataset({
#     features: ['instruction', 'input', 'output'],
#     num_rows: 991
# })

# %%
new_tested[0]
# Out:
# {'instruction': "Given the subject entity 'Nashville North', extract the full triple from the sentence.",
#  'input': 'The rarified space is the cavernous outdoor concert location in the middle of the Calgary Stampede grounds that’s known as Nashville North, where people lingering at picnic tables sip Molson Canadian and Budweiser as musicians belt out covers of Tim McGraw and Toby Keith.',
#  'output': "['Nashville North', 'known_as', 'outdoor concert']"}

# %%
new_tested[1]
# Out:
# {'instruction': "Given the subject entity 'Tim McGraw', extract the full triple from the sentence.",
#  'input': 'The rarified space is the cavernous outdoor concert location in the middle of the Calgary Stampede grounds that’s known as Nashville North, where people lingering at picnic tables sip Molson Canadian and Budweiser as musicians belt out covers of Tim McGraw and Toby Keith.',
#  'output': "['Tim McGraw', 'job_title', 'musician']"}

# %%
new_tested[2]
# Out:
# {'instruction': "Given the subject entity 'Toby Keith', extract the full triple from the sentence.",
#  'input': 'The rarified space is the cavernous outdoor concert location in the middle of the Calgary Stampede grounds that’s known as Nashville North, where people lingering at picnic tables sip Molson Canadian and Budweiser as musicians belt out covers of Tim McGraw and Toby Keith.',
#  'output': "['Toby Keith', 'job_title', 'musician']"}

# %%
new_tested[3]
# Out:
# {'instruction': "Given the subject entity 'people', extract the full triple from the sentence.",
#  'input': 'The rarified space is the cavernous outdoor concert location in the middle of the Calgary Stampede grounds that’s known as Nashville North, where people lingering at picnic tables sip Molson Canadian and Budweiser as musicians belt out covers of Tim McGraw and Toby Keith.',
#  'output': "['people', 'sip', 'Molson Canadian']"}

# %%
new_tested[4]
# Out:
# {'instruction': "Given the subject entity 'people', extract the full triple from the sentence.",
#  'input': 'The rarified space is the cavernous outdoor concert location in the middle of the Calgary Stampede grounds that’s known as Nashville North, where people lingering at picnic tables sip Molson Canadian and Budweiser as musicians belt out covers of Tim McGraw and Toby Keith.',
#  'output': "['people', 'sip', 'Budweiser']"}

# %%
new_tested[5]
# Out:
# {'instruction': "Given the subject entity 'musicians', extract the full triple from the sentence.",
#  'input': 'The rarified space is the cavernous outdoor concert location in the middle of the Calgary Stampede grounds that’s known as Nashville North, where people lingering at picnic tables sip Molson Canadian and Budweiser as musicians belt out covers of Tim McGraw and Toby Keith.',
#  'output': "['musicians', 'belt', 'covers']"}

# %%
new_tested[5]
# Out:
# {'instruction': "Given the subject entity 'musicians', extract the full triple from the sentence.",
#  'input': 'The rarified space is the cavernous outdoor concert location in the middle of the Calgary Stampede grounds that’s known as Nashville North, where people lingering at picnic tables sip Molson Canadian and Budweiser as musicians belt out covers of Tim McGraw and Toby Keith.',
#  'output': "['musicians', 'belt', 'covers']"}
